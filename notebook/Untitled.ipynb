# %%
import time, datetime
import numpy as np
from numpy import zeros, sqrt, pi, vectorize
from numpy.linalg import pinv, inv
from multiprocessing import Process, Queue
#import matplotlib
#matplotlib.use('Qt4Agg')
import matplotlib.pyplot as plt
from error_analysis_class import *
from noshellavg import *
from matplotlib.backends.backend_pdf import PdfPages
from run_error_analysis import *
from plot_error import *
import sys
import argparse
import yaml
from utils import *
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# /n/home00/lee.5922/.local/lib/python2.7/site-packages/subprocess32.py:472: RuntimeWarning: The _posixsubprocess module is not being used. Child process reliability may suffer if your program uses threads.
#   "program uses threads.", RuntimeWarning)

# %%
yaml_file = 'yaml/sanchez_bfsn_kN500_rN140.yaml'
params = yaml.load(open(yaml_file))

# %%
kmin, kmax, kN = params['k']
kmin = 0.001
kN = 500
rmin, rmax, rN = params['r']
logscale = params['logscale']
KMIN, KMAX = 1e-3, 2.0
lmax = params['lmax']
#parameter_ind = [0,1,2] #params['parameter_ind']   

b = 2.0
if 'b' in params: b = params['b']
f = 0.74
if 'f' in params: f = params['f']
s = 3.5
if 's' in params: s = params['s']
nn = 3.0 * 10**(-4) #1/n
if 'nn' in params: nn = params['nn']

RSDPower = NoShell_covariance(KMIN, KMAX, rmin, rmax, 2**10 + 1, rN, 1, kN, b,f,s,nn,logscale = logscale)
Covariance_matrix(params, RSDPower)


if 'multipole_p_filename' not in params:
    P_multipole(params, RSDPower)
else : print '\nUse Precalculated multipole_p ', params['multipole_p_filename']

if 'derivative_P_filename' not in params:
    derivative_P_datavector(params, RSDPower)
else : print 'Use Precalculated derivative_P ', params['derivative_P_filename']     


if 'derivative_Xi_filename' not in params:
    derivative_Xi_datavector(params, RSDPower)
else : print 'Use Precalculated derivative_Xi ', params['derivative_Xi_filename']    

if 'params_datavector_filename' not in params:
    params_datavector(params, RSDPower)
else : print '\nUse Precalculated params_datavector ', params['params_datavoector_filename']     


BandpowerFisher(params, RSDPower, kmin = kmin, kmax = kmax, lmax = lmax) 
Fisher_params(params, RSDPower, parameter = parameter_ind, kmin=kmin, kmax=kmax, lmax=lmax)
# Out:
# -------------------------------------------------------------------
# class error_analysis, no RSD
# z = 0.0, kN =1025, N_y = 500, rN = 141
# dr = 1.0, dk=0.0019521484375, dk_y=0.00400601202405
# /n/home00/lee.5922/.local/lib/python2.7/site-packages/scipy/integrate/quadrature.py:392: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   x = x.reshape(tuple(shapex))
# /n/home00/lee.5922/.local/lib/python2.7/site-packages/scipy/integrate/quadrature.py:392: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   x = x.reshape(tuple(shapex))
# /n/home00/lee.5922/.local/lib/python2.7/site-packages/scipy/integrate/quadrature.py:392: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   x = x.reshape(tuple(shapex))
# multiprocessing 100 %
# ...

# %%
from plot_error import * 
#sanchez = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
sanchez_bfsn = 'data_txt/sanchez_bfsn_kN500_rN140_fisher_params_nn.txt'
text_label = '   k = [0,0.25] h/Mpc (Grieb) \n   r = [20,160] Mpc/h (Sanchez)\n'

plot_triple_ellipse([sanchez_bfsn], parameter_name = [r'$b$', r'$f$', r'$\sigma_v$']\
                 , parameter_truth = [2.0, 0.74, 3.5], diffsky=1
                 , extent =[[0.975, 1.025], [0.85, 1.15], [0.5, 1.5]]
                 , text_label = text_label, out_name = 'figure/test.png')

#plot_triple_ellipse([sanchez_bfsn], parameter_name = [r'$b$', r'$f$', r'$\sigma_v$']\
#                 , parameter_truth = [2.0, 0.74, 3.5], diffsky=0
#                 , extent =[[0.975, 1.025], [0.85, 1.15], [0.5, 1.5]]
#                 , text_label = text_label, out_name = 'figure/test.png')

# %%
# first terms

shell_dat = np.genfromtxt('data_txt/c_pxi_last_noshell.dat')
noshell_dat = np.genfromtxt('data_txt/c_pxi_last_term.dat')
full_ksh_dat = np.genfromtxt('data_txt/c_pxi_full_kshell.dat')
fig, ax = plt.subplots()
print RSDPower.kcenter[10], RSDPower.kcenter[24]
ax.plot(RSDPower.rcenter, shell_dat[:,1], label = 'k={:>0.3f}, shell'.format(RSDPower.kcenter[10]))
#ax.plot(RSDPower.rcenter, shell_dat[:,2], label = 'k={:>0.3f}, shell'.format(RSDPower.kcenter[25]))
ax.plot(RSDPower.rcenter, noshell_dat[:,1], label = 'k={:>0.3f}, noshell'.format(RSDPower.kcenter[10]))
#ax.plot(RSDPower.rcen|ter, noshell_dat[:,2], label = 'k={:>0.3f}, noshell'.format(RSDPower.kcenter[25]))
ax.plot(RSDPower.rcenter, full_ksh_dat[:,1], label = 'k={:>0.3f}, correct'.format(RSDPower.kcenter[10]))
#ax.plot(RSDPower.rcenter, full_ksh_dat[:,2], label = 'k={:>0.3f}, noshell'.format(RSDPower.kcenter[25]))
ax.legend()
#ax.set_ylim(-0.03,0.05)
ax.set_ylabel(r'$C_{p\xi}(k,r)$', fontsize=15)
ax.set_xlabel(r'$r$', fontsize = 20)
# Out:
# 0.0215270833928 0.0488406429321

# %%
# first terms

shell_dat = np.genfromtxt('data_txt/c_pxi_first_noshell.dat')
noshell_dat = np.genfromtxt('data_txt/c_pxi_first_term.dat')
fig, ax = plt.subplots()
print RSDPower.kcenter_y[10], RSDPower.kcenter_y[24]
ax.plot(RSDPower.rcenter, shell_dat[:,1], label = 'k={:>0.3f}, shell'.format(RSDPower.kcenter_y[10]))
ax.plot(RSDPower.rcenter, shell_dat[:,2], label = 'k={:>0.3f}, shell'.format(RSDPower.kcenter_y[25]))
ax.plot(RSDPower.rcenter, noshell_dat[:,1], label = 'k={:>0.3f}, noshell'.format(RSDPower.kcenter_y[10]))
ax.plot(RSDPower.rcenter, noshell_dat[:,2], label = 'k={:>0.3f}, noshell'.format(RSDPower.kcenter_y[25]))
ax.legend()
ax.set_ylim(-0.03,0.05)
ax.set_ylabel('C_pxi(k,r)')
ax.set_xlabel('r')
# Out:
# 0.106632707818 0.247176089163

# %%
# first term, no shell avg
fig, ax = plt.subplots()
print RSDPower.kcenter[10], RSDPower.kcenter[24]
ax.plot(RSDPower.rcenter, covPXi00[10,:], label = 'k={:>0.3f}'.format(RSDPower.kcenter[10]))
ax.plot(RSDPower.rcenter, covPXi00[24,:], label = 'k={:>0.3f}'.format(RSDPower.kcenter[25]))
ax.legend()
#ax.set_ylim(-0.03,0.05)
ax.set_ylabel('C_pxi(k,r)')
ax.set_xlabel('r')
# Out:
# 0.0215270833928 0.0488406429321

# %%
# first term + last Term, shell avg
fig, ax = plt.subplots()
print RSDPower.kcenter_y[10], RSDPower.kcenter_y[24]
ax.plot(RSDPower.rcenter, covPXi00[10,:], label = 'k={:>0.3f}'.format(RSDPower.kcenter_y[10]))
ax.plot(RSDPower.rcenter, covPXi00[24,:], label = 'k={:>0.3f}'.format(RSDPower.kcenter_y[25]))
ax.legend()
ax.set_ylabel('C_pxi(k,r)')
ax.set_xlabel('r')
# Out:
# 0.106632707818 0.247176089163

# %%
# first term, shell avg
fig, ax = plt.subplots()
print RSDPower.kcenter_y[10], RSDPower.kcenter_y[24]
ax.plot(RSDPower.rcenter, covPXi00[10,:], label = 'k={:>0.3f}'.format(RSDPower.kcenter_y[10]))
ax.plot(RSDPower.rcenter, covPXi00[24,:], label = 'k={:>0.3f}'.format(RSDPower.kcenter_y[25]))
ax.legend()
ax.set_ylabel('C_pxi(k,r)')
ax.set_xlabel('r')
# Out:
# 0.106632707818 0.247176089163

# %%
# last term, shell avg
fig, ax = plt.subplots()
print RSDPower.kcenter[10], RSDPower.kcenter[24]
ax.plot(RSDPower.rcenter, covPXi00[10,:], label = 'k={:>0.3f}'.format(RSDPower.kcenter[10]))
ax.plot(RSDPower.rcenter, covPXi00[24,:], label = 'k={:>0.3f}'.format(RSDPower.kcenter[25]))
ax.legend()
ax.set_ylabel('C_pxi(k,r)')
ax.set_xlabel('r')
# Out:
# 0.0215270833928 0.0488406429321

# %%
DAT = np.column_stack((RSDPower.rcenter,covPXi00[10,:], covPXi00[24,:] ))
#np.savetxt('data_txt/c_pxi_full_kshell.dat', DAT, header='rcenter, k=0.022, k=0.051')

# %%
# r shell avg
fig, ax = plt.subplots()
print RSDPower.kcenter[10], RSDPower.kcenter[24]
ax.plot(RSDPower.rcenter, covPXi00[10,:])
ax.plot(RSDPower.rcenter, covPXi00[24,:])
# Out:
# 0.0215270833928 0.0488406429321

# %%
# raw 7x7 matrix
params_fisher7x7 = np.genfromtxt('data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_7x7.txt')[:,1].reshape(7,7)
corr_params_cov7x7 = correlation_matrix(inv(params_fisher7x7))

# project it to b,f,n, leaving s1 s2.
datav_q = np.zeros((5,7))
datav_q[0][0] = 1.
datav_q[1][1] = 1.
datav_q[2][2] = 1.
datav_q[4][3] = 1.
datav_q[0][4] = 1.
datav_q[1][5] = 1.
datav_q[3][6] = 1. 

params_fisher5x5 = FisherProjection_Fishergiven(datav_q, params_fisher7x7)
corr_params_cov5x5 = correlation_matrix(inv(params_fisher5x5))
DAT5 = np.column_stack(( np.arange(25), params_fisher5x5.ravel() ))
np.savetxt('data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_5x5.txt', DAT5)

# project it to b,f,n,s
datav_q4 = np.zeros((4,7))
datav_q4[0][0] = 1.
datav_q4[1][1] = 1.
datav_q4[2][2] = 1.
datav_q4[3][3] = 1.
datav_q4[0][4] = 1.
datav_q4[1][5] = 1.
datav_q4[2][6] = 1.   

#F_params_tot_q = np.dot( np.dot( datav_q, Fq ), datav_q.T)
params_fisher4x4 = FisherProjection_Fishergiven(datav_q4, params_fisher7x7)
DAT4 = np.column_stack(( np.arange(16), params_fisher4x4.ravel() ))
np.savetxt('data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_4x4.txt', DAT4)

corr_params_cov4x4 = np.corrcoef(inv(params_fisher4x4))

# %%
#TEST 1 

fig, (ax, ax2) = plt.subplots(1,2, figsize = (14,6))
im = ax.imshow(params_fisher7x7, interpolation = 'none')
im2 = ax2.imshow(corr_params_cov7x7, interpolation = 'none')
fig.colorbar(im, ax=ax)
fig.colorbar(im2, ax=ax2)


printout_matrix_component(corr_params_cov7x7)
ax.set_xticks(np.arange(0, 7, 1));
ax.set_yticks(np.arange(0, 7, 1));
ax.set_xticklabels([r'$b$', r'$f$', r'$\sigma_{v,p}$', r'$1/\bar{n}$',r'$b$', r'$f$', r'$\sigma_{v,\xi}$']);
ax.set_yticklabels([r'$b$', r'$f$', r'$\sigma_{v,p}$', r'$1/\bar{n}$',r'$b$', r'$f$', r'$\sigma_{v,\xi}$']);
ax.set_title('Fisher')
ax2.set_xticks(np.arange(0, 7, 1));
ax2.set_yticks(np.arange(0, 7, 1));
ax2.set_xticklabels([r'$b$', r'$f$', r'$\sigma_{v,p}$', r'$1/\bar{n}$',r'$b$', r'$f$', r'$\sigma_{v,\xi}$']);
ax2.set_yticklabels([r'$b$', r'$f$', r'$\sigma_{v,p}$', r'$1/\bar{n}$',r'$b$', r'$f$', r'$\sigma_{v,\xi}$']);
ax2.set_title('corr')



plot_single_ellipse(['data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_7x7.txt']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v,p}$', r'\bar{n}',r'$b$', r'$f$', r'$\sigma_{v,\xi}$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 10**4/3., 2.0, 0.74, 3.5], keep = [2,6]\
                 , extent =[[0.975, 1.025], [0.85, 1.15], [0.6, 1.4],[0.95, 1.05], [0.95, 1.05],[0.95, 1.05], [0.6, 1.4]]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')
# Out:
# [  1.000e+00  -7.662e-01  -7.044e-01  -8.636e-01  9.974e-01  -7.644e-01  -6.829e-01]
# [  -7.662e-01  1.000e+00  8.654e-01  6.615e-01  -7.640e-01  9.992e-01  8.437e-01]
# [  -7.044e-01  8.654e-01  1.000e+00  7.934e-01  -7.020e-01  8.660e-01  9.814e-01]
# [  -8.636e-01  6.615e-01  7.934e-01  1.000e+00  -8.637e-01  6.606e-01  7.716e-01]
# [  9.974e-01  -7.640e-01  -7.020e-01  -8.637e-01  1.000e+00  -7.639e-01  -6.876e-01]
# [  -7.644e-01  9.992e-01  8.660e-01  6.606e-01  -7.639e-01  1.000e+00  8.510e-01]
# [  -6.829e-01  8.437e-01  9.814e-01  7.716e-01  -6.876e-01  8.510e-01  1.000e+00]
# cov_tot_keeped_matrix
# [[ 0.06356982  0.06409234]
#  [ 0.06409234  0.06709614]]

# %%
params_fisher7x7.shape
# Out:
# (7, 7)

# %%
params_f_p
# Out:
# array([[  2.56910935e+05,   7.24323566e+04,  -3.50791834e+03,
#           7.07558934e+01],
#        [  7.24323566e+04,   4.04970878e+04,  -2.03247630e+03,
#           2.11004455e+01],
#        [ -3.50791834e+03,  -2.03247630e+03,   1.45588637e+02,
#          -1.51154975e+00],
#        [  7.07558934e+01,   2.11004455e+01,  -1.51154975e+00,
#           2.81356886e-02]])

# %%
params_fisher7x7 = np.genfromtxt('data_txt/test_bfsn_k0_02_kN500_r18_180_rN162_fisher_params_7x7.txt')[:,1].reshape(7,7)
params_f_p = np.genfromtxt('data_txt/test_bfsn_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt')[:,1].reshape(4,4)
params_f_xi = np.genfromtxt('data_txt/test_bfsn_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt')[:,2].reshape(4,4)
params_f_tot = np.genfromtxt('data_txt/test_bfsn_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt')[:,3].reshape(4,4)

# %%
printout_matrix_component(params_fisher7x7)
# Out:
# [  2.954e+06  1.619e+06  -2.997e+03  -1.732e+01  -2.882e+06  -1.602e+06  4.570e+03]
# [  1.619e+06  4.912e+06  -4.853e+04  8.492e-01  -1.582e+06  -4.873e+06  4.691e+04]
# [  -2.997e+03  -4.853e+04  8.860e+02  -1.916e+00  -1.180e+03  4.595e+04  -6.911e+02]
# [  -1.732e+01  8.492e-01  -1.916e+00  2.771e-02  8.731e+01  2.000e+01  4.307e-01]
# [  -2.882e+06  -1.582e+06  -1.180e+03  8.731e+01  3.064e+06  1.637e+06  -3.850e+03]
# [  -1.602e+06  -4.873e+06  4.595e+04  2.000e+01  1.637e+06  4.873e+06  -4.634e+04]
# [  4.570e+03  4.691e+04  -6.911e+02  4.307e-01  -3.850e+03  -4.634e+04  6.390e+02]

# %%
printout_matrix_component(inv(params_fisher7x7))
# Out:
# [  3.167e-05  -6.119e-05  -1.007e-03  -8.809e-02  3.169e-05  -6.111e-05  -1.006e-03]
# [  -6.119e-05  2.032e-04  3.172e-03  1.694e-01  -6.105e-05  2.039e-04  3.260e-03]
# [  -1.007e-03  3.172e-03  6.635e-02  3.647e+00  -1.011e-03  3.205e-03  6.994e-02]
# [  -8.809e-02  1.694e-01  3.647e+00  3.298e+02  -8.942e-02  1.698e-01  3.693e+00]
# [  3.169e-05  -6.105e-05  -1.011e-03  -8.942e-02  3.228e-05  -6.146e-05  -1.041e-03]
# [  -6.111e-05  2.039e-04  3.205e-03  1.698e-01  -6.146e-05  2.058e-04  3.374e-03]
# [  -1.006e-03  3.260e-03  6.994e-02  3.693e+00  -1.041e-03  3.374e-03  8.103e-02]

# %%
printout_matrix_component(inv(params_f_p) )
# Out:
# [  9.464e-05  -1.588e-04  -4.713e-03  -5.315e-01]
# [  -1.588e-04  4.802e-04  1.386e-02  8.579e-01]
# [  -4.713e-03  1.386e-02  4.953e-01  3.071e+01]
# [  -5.315e-01  8.579e-01  3.071e+01  3.571e+03]

# %%
printout_matrix_component(inv(params_f_xi) )
# Out:
# [  1.078e-04  -1.434e-04  -4.740e-03  0.000e+00]
# [  -1.434e-04  3.675e-04  1.139e-02  0.000e+00]
# [  -4.740e-03  1.139e-02  4.829e-01  0.000e+00]
# [  0.000e+00  0.000e+00  0.000e+00  1.000e+20]

# %%
printout_matrix_component(params_f_xi )
# Out:
# [  1.952e+04  6.230e+03  4.462e+01  0.000e+00]
# [  6.230e+03  1.210e+04  -2.241e+02  0.000e+00]
# [  4.462e+01  -2.241e+02  7.794e+00  0.000e+00]
# [  0.000e+00  0.000e+00  0.000e+00  1.000e-20]

# %%
printout_matrix_component(inv(params_fisher7x7))
# Out:
# [  3.167e-05  -6.119e-05  -1.007e-03  -8.809e-02  3.169e-05  -6.111e-05  -1.006e-03]
# [  -6.119e-05  2.032e-04  3.172e-03  1.694e-01  -6.105e-05  2.039e-04  3.260e-03]
# [  -1.007e-03  3.172e-03  6.635e-02  3.647e+00  -1.011e-03  3.205e-03  6.994e-02]
# [  -8.809e-02  1.694e-01  3.647e+00  3.298e+02  -8.942e-02  1.698e-01  3.693e+00]
# [  3.169e-05  -6.105e-05  -1.011e-03  -8.942e-02  3.228e-05  -6.146e-05  -1.041e-03]
# [  -6.111e-05  2.039e-04  3.205e-03  1.698e-01  -6.146e-05  2.058e-04  3.374e-03]
# [  -1.006e-03  3.260e-03  6.994e-02  3.693e+00  -1.041e-03  3.374e-03  8.103e-02]

# %%
printout_matrix_component(corr_params_cov7x7)
# Out:
# [  1.000e+00  -7.662e-01  -7.044e-01  -8.636e-01  9.974e-01  -7.644e-01  -6.829e-01]
# [  -7.662e-01  1.000e+00  8.654e-01  6.615e-01  -7.640e-01  9.992e-01  8.437e-01]
# [  -7.044e-01  8.654e-01  1.000e+00  7.934e-01  -7.020e-01  8.660e-01  9.814e-01]
# [  -8.636e-01  6.615e-01  7.934e-01  1.000e+00  -8.637e-01  6.606e-01  7.716e-01]
# [  9.974e-01  -7.640e-01  -7.020e-01  -8.637e-01  1.000e+00  -7.639e-01  -6.876e-01]
# [  -7.644e-01  9.992e-01  8.660e-01  6.606e-01  -7.639e-01  1.000e+00  8.510e-01]
# [  -6.829e-01  8.437e-01  9.814e-01  7.716e-01  -6.876e-01  8.510e-01  1.000e+00]

# %%
plot_fisher_corr_matrix(params_fisher4x4)
plot_fisher_corr_matrix(params_fisher5x5)
plot_fisher_corr_matrix(params_fisher7x7)
# Out:
# [[  2.56910935e+05   7.24323566e+04  -3.50791834e+03   7.07558934e+01]
#  [  7.24323566e+04   4.04970878e+04  -2.03247630e+03   2.11004455e+01]
#  [ -3.50791834e+03  -2.03247630e+03   1.45588637e+02  -1.51154975e+00]
#  [  7.07558934e+01   2.11004455e+01  -1.51154975e+00   2.81356886e-02]]
# array([[ 1.        , -0.76483865, -0.70336222, -0.86386744],
#        [-0.76483865,  1.        ,  0.86455601,  0.66075622],
#        [-0.70336222,  0.86455601,  1.        ,  0.79508834],
#        [-0.86386744,  0.66075622,  0.79508834,  1.        ]])

# %%
# TEST 2
text_label = '   k = [0,0.2] h/Mpc  \n   r = [20,160] Mpc/h (Sanchez)\n'
plot_single_ellipse(['data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_5x5.txt',
                    'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_4x4.txt']
                 , linestyle = ['solid', 'dashed']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v,p}$', r'\bar{n}',r'$b$', r'$f$', r'$\sigma_{v,\xi}$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 10**4/3., 2.0, 0.74, 3.5], keep = [0,1]\
                 , extent =[[0.975, 1.025], [0.85, 1.15], [0.6, 1.4],[0.95, 1.05], [0.95, 1.05],[0.95, 1.05], [0.6, 1.4]]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')
# Out:
# cov_tot_keeped_matrix
# [[  3.10356888e-05  -6.00699145e-05]
#  [ -6.00699145e-05   1.98805658e-04]]

# %%
#TEST 4 Full case 

params_fisher_full7x7 = np.genfromtxt('data_txt/default_kN500_ke-10_rN180_re-3_bfsn_fisher_params_7x7.txt')[:,1].reshape(7,7)
plot_fisher_corr_matrix(params_fisher_full7x7)
printout_matrix_component(params_fisher_full7x7)

# project it to b,f,n, leaving s1 s2.
datav_q = np.zeros((5,7))
datav_q[0][0] = 1.
datav_q[1][1] = 1.
datav_q[2][2] = 1.
datav_q[4][3] = 1.
datav_q[0][4] = 1.
datav_q[1][5] = 1.
datav_q[3][6] = 1. 

params_fisher_full5x5 = FisherProjection_Fishergiven(datav_q, params_fisher_full7x7)
corr_params_cov5x5 = correlation_matrix(inv(params_fisher_full5x5))
DAT5 = np.column_stack(( np.arange(25), params_fisher_full5x5.ravel() ))
np.savetxt('data_txt/default_kN500_ke-10_rN180_re-3_bfsn_fisher_params_5x5.txt', DAT5)
printout_matrix_component(params_fisher_full5x5)
plot_fisher_corr_matrix(params_fisher_full5x5)

params_fisher_full = np.genfromtxt('data_txt/default_kN500_ke-10_rN180_re-3_bfsn_fisher_params_nn.txt')[:,3].reshape(4,4)
plot_fisher_corr_matrix(params_fisher_full)

print '\nfisher\n'
print params_fisher_full
print '\nfullscale cov \n'
print inv(params_fisher_full)

correlation_matrix(inv(params_fisher_full))
# Out:
# [  6.492e+08  1.630e+08  -3.844e+06  1.273e+05  -6.477e+08  -1.628e+08  3.790e+06]
# [  1.630e+08  1.634e+08  -6.200e+06  3.462e+04  -1.627e+08  -1.633e+08  6.185e+06]
# [  -3.844e+06  -6.200e+06  3.412e+05  -2.429e+03  3.829e+06  6.198e+06  -3.403e+05]
# [  1.273e+05  3.462e+04  -2.429e+03  2.779e+02  -1.264e+05  -3.452e+04  2.388e+03]
# [  -6.477e+08  -1.627e+08  3.829e+06  -1.264e+05  6.468e+08  1.626e+08  -3.784e+06]
# [  -1.628e+08  -1.633e+08  6.198e+06  -3.452e+04  1.626e+08  1.633e+08  -6.186e+06]
# [  3.790e+06  6.185e+06  -3.403e+05  2.388e+03  -3.784e+06  -6.186e+06  3.399e+05]
# [  4.415e+05  9.598e+04  -1.506e+04  6.397e+03  9.220e+02]
# [  9.598e+04  4.927e+04  -2.705e+03  -9.472e+02  9.548e+01]
# [  -1.506e+04  -2.705e+03  3.412e+05  -3.403e+05  -2.429e+03]
# [  6.397e+03  -9.472e+02  -3.403e+05  3.399e+05  2.388e+03]
# [  9.220e+02  9.548e+01  -2.429e+03  2.388e+03  2.779e+02]
#
# fisher
#
# [[  4.41514048e+05   9.59753530e+04  -8.65858528e+03   9.21953655e+02]
# ...

# %%
params_fisher_p = np.genfromtxt('data_txt/default_kN500_ke-10_rN180_re-3_bfsn_fisher_params_nn.txt')[:,1].reshape(4,4)
params_fisher_xi = np.genfromtxt('data_txt/default_kN500_ke-10_rN180_re-3_bfsn_fisher_params_nn.txt')[:,2].reshape(4,4)
params_fisher_tot = np.genfromtxt('data_txt/default_kN500_ke-10_rN180_re-3_bfsn_fisher_params_nn.txt')[:,3].reshape(4,4)

# %%
params_fisher_p
# Out:
# array([[  4.39730225e+05,   9.57523885e+04,  -8.57836257e+03,
#           7.16818499e+02],
#        [  9.57523885e+04,   4.92197793e+04,  -3.64291415e+03,
#           8.81189980e+01],
#        [ -8.57836257e+03,  -3.64291415e+03,   4.97455831e+02,
#          -3.12803164e+01],
#        [  7.16818499e+02,   8.81189980e+01,  -3.12803164e+01,
#           2.98998743e+01]])

# %%
params_fisher_xi
# Out:
# array([[  4.35546902e+05,   9.51710942e+04,  -8.40312782e+03,
#           0.00000000e+00],
#        [  9.51710942e+04,   4.91415085e+04,  -3.61791355e+03,
#           0.00000000e+00],
#        [ -8.40312782e+03,  -3.61791355e+03,   4.90044609e+02,
#           0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e-20]])

# %%
params_fisher_tot
# Out:
# array([[  4.41514048e+05,   9.59753530e+04,  -8.65858528e+03,
#           9.21953655e+02],
#        [  9.59753530e+04,   4.92691684e+04,  -3.65225137e+03,
#           9.54798746e+01],
#        [ -8.65858528e+03,  -3.65225137e+03,   5.01562758e+02,
#          -4.16103027e+01],
#        [  9.21953655e+02,   9.54798746e+01,  -4.16103027e+01,
#           2.77878511e+02]])

# %%
# Test 4_1
#params_fisher_p = np.genfromtxt('data_txt/default_kN500_ke-10_rN180_re-3_bfsn_fisher_params_nn.txt')[:,1].reshape(4,4)
#params_fisher_xi = np.genfromtxt('data_txt/default_kN500_ke-10_rN180_re-3_bfsn_fisher_params_nn.txt')[:,2].reshape(4,4)
#params_fisher_com = np.genfromtxt('data_txt/default_kN500_ke-10_rN180_re-3_bfsn_fisher_params_nn.txt')[:,3].reshape(4,4)
#difference = params_fisher_p - params_fisher_xi
#DAT = np.column_stack((np.arange(16), params_fisher_p.ravel(),params_fisher_xi.ravel(),params_fisher_com.ravel(), difference.ravel()))
#np.savetxt('data_txt/params_p-params_xi.dat', DAT)

# %%
# Test 4_1
params_fisher_p = np.genfromtxt('data_txt/test_bfsn_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt')[:,1].reshape(4,4)
params_fisher_xi = np.genfromtxt('data_txt/test_bfsn_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt')[:,2].reshape(4,4)
params_fisher_com = np.genfromtxt('data_txt/test_bfsn_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt')[:,3].reshape(4,4)
difference = params_fisher_p - params_fisher_xi
DAT = np.column_stack((np.arange(16), difference.ravel()))
#DAT = np.column_stack((np.arange(16), params_fisher_p.ravel(),params_fisher_xi.ravel(),params_fisher_com.ravel(), difference.ravel()))
np.savetxt('data_txt/params_p-params_xi.dat', DAT)

# %%
print params_fisher_p
print difference
# Out:
# [[  1.33662047e+05   3.93748731e+04  -1.01698569e+03   1.91347928e+01]
#  [  3.93748731e+04   2.23800808e+04  -6.00345000e+02   5.64554169e+00]
#  [ -1.01698569e+03  -6.00345000e+02   2.03936275e+01  -1.82509818e-01]
#  [  1.91347928e+01   5.64554169e+00  -1.82509818e-01   3.33128186e-03]]
# [[  1.14145810e+05   3.31444857e+04  -1.06160553e+03   1.91347928e+01]
#  [  3.31444857e+04   1.02833418e+04  -3.76226229e+02   5.64554169e+00]
#  [ -1.06160553e+03  -3.76226229e+02   1.25997257e+01  -1.82509818e-01]
#  [  1.91347928e+01   5.64554169e+00  -1.82509818e-01   3.33128186e-03]]

# %%
fisher_params_filename = []
plot_triple_ellipse(fisher_params_filename, parameter_name = [r'$b$', r'$f$', r'$\sigma_v$', r'1/n']\
                 , linecolor = ['b', 'r', 'g', 'c' ,'b', 'r', 'g', 'y', 'c', 'k']
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid']
                 , parameter_truth = [2.0, 0.74, 3.5, 1e+4/3.], diffsky=0, dnn=0
                 , keeps = [[0,1], [0,2], [1,2],[0,3], [1,3], [2,3]]
                 #, extent =[[0.975, 1.025], [0.85, 1.15], [0.5, 1.5], [0.95, 1.05],[0.85, 1.15],[0.75, 1.25]]
                 , extent =[[0.975, 1.025], [0.85, 1.15], [0.5, 1.5], [0.95, 1.05],[0.85, 1.15],[0.75, 1.25]]
                 , text_label = text_label, out_name = 'test.png')
# Out:
# [[  2.32122213e-04   8.64944086e-05   3.41069116e-03  -1.29302587e+00]
#  [  8.64944086e-05  -9.61316741e-04  -2.42975721e-02  -1.98855677e-01]
#  [  3.41069116e-03  -2.42975721e-02  -2.23354893e-01   9.34944198e+00]
#  [ -1.29302587e+00  -1.98855677e-01   9.34944198e+00   8.57651688e+03]]
# [[  2.32122213e-04   8.64944086e-05   3.41069116e-03  -1.29302587e+00]
#  [  8.64944086e-05  -9.61316741e-04  -2.42975721e-02  -1.98855677e-01]
#  [  3.41069116e-03  -2.42975721e-02  -2.23354893e-01   9.34944198e+00]
#  [ -1.29302587e+00  -1.98855677e-01   9.34944198e+00   8.57651688e+03]]
# [[  2.32122213e-04   8.64944086e-05   3.41069116e-03  -1.29302587e+00]
#  [  8.64944086e-05  -9.61316741e-04  -2.42975721e-02  -1.98855677e-01]
#  [  3.41069116e-03  -2.42975721e-02  -2.23354893e-01   9.34944198e+00]
#  [ -1.29302587e+00  -1.98855677e-01   9.34944198e+00   8.57651688e+03]]
# [[  2.32122213e-04   8.64944086e-05   3.41069116e-03  -1.29302587e+00]
# ...

# %%
# TEST 2 

params_fisher7x7 = np.genfromtxt('data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_7x7.txt')[:,1].reshape(7,7)
C_7x7 = inv(params_fisher7x7)
params_fisher_p = np.genfromtxt('data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt')[:,1].reshape(4,4)
C_p = inv(params_fisher_p)

# A type
# 1) marginalizing s1, s2, 1/n
mask_sn_mar = np.ones((7,7), dtype=bool)
mask_sn_mar[:,2] = 0
mask_sn_mar[2,:] = 0
mask_sn_mar[:,3] = 0
mask_sn_mar[3,:] = 0
mask_sn_mar[:,-1] = 0
mask_sn_mar[-1,:] = 0
Ca1 = C_7x7[mask_sn_mar].reshape(4,4)
Fa1 = inv(C1)  # <- b,f,b,f fisher

# Project b,f,b,f to the same b,f
datav_a = np.zeros((2,4))
datav_a[0][0] =1
datav_a[1][1] =1
datav_a[0][2] =1
datav_a[1][3] =1
Fa2 = np.dot( np.dot(datav_a, Fa1), datav_a.T )
Ca2 = inv(Fa2) # b,f covariance 


# B type
# project 7x7 fisher to b,f,s,1/n 
datav_b = np.zeros((4,7))
datav_b[0][0] = 1.
datav_b[1][1] = 1.
datav_b[2][2] = 1.
datav_b[3][3] = 1.
datav_b[0][4] = 1.
datav_b[1][5] = 1.
datav_b[2][6] = 1.   

Fb1 = np.dot( np.dot(datav_b, params_fisher7x7), datav_b.T ) # <- b,f,s,1/n fisher
Cb1 = inv(Fb1)
Cb2 = Cb1[:2, :2] # marginalizing s, 1/n  <- b,f covariance for ellipse
Fb2 = inv(Cb2)

# %%
printout_matrix_component(Ca1)
# Out:
# [  3.129e-05  -6.071e-05  3.111e-05  -6.064e-05]
# [  -6.071e-05  2.006e-04  -6.033e-05  2.007e-04]
# [  3.111e-05  -6.033e-05  3.108e-05  -6.041e-05]
# [  -6.064e-05  2.007e-04  -6.041e-05  2.011e-04]

# %%
DAT = np.column_stack((np.arange(4), Fa2.ravel(), Fb2.ravel()))
np.savetxt('data_txt/test2_marginalization_test_fisher.dat', DAT)

# %%
# TEST 2
text_label = '   k = [0,0.2] h/Mpc  \n   r = [20,160] Mpc/h (Sanchez)\n'
plot_single_ellipse(#['data_txt/test2_marginalization_test_fisher.dat']
                    ['data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt']
                 , linestyle = ['solid', 'dashed', 'solid']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v,p}$', r'\bar{n}',r'$b$', r'$f$', r'$\sigma_{v,\xi}$']\
                 , parameter_truth = [2.0, 0.74], keep = [0,1]\
                 , extent =[[0.975, 1.025], [0.85, 1.15]]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')
# Out:
# cov_tot_keeped_matrix
# [[  9.49793253e-05  -1.59367034e-04]
#  [ -1.59367034e-04   4.81841720e-04]]

# %%
inv(params_fisher7x7[:4, :4])[1][1]
# Out:
# 2.8124991487157103e-07

# %%
# TEST 2 ( b, f, s)

params_fisher7x7 = np.genfromtxt('data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_7x7.txt')[:,1].reshape(7,7)
C_7x7 = inv(params_fisher7x7)
params_fisher_p = np.genfromtxt('data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt')[:,1].reshape(4,4)
C_p = inv(params_fisher_p)



# marginalizing 1/n
mask_sn_mar = np.ones((7,7), dtype=bool)
mask_sn_mar[:,3] = 0
mask_sn_mar[3,:] = 0
Ca6x6 = C_7x7[mask_sn_mar].reshape(6,6)
Fa6x6 = inv(Ca6x6)  # <- b,f,b,f fisher


print 'sum of fist F', np.sum(Fa6x6)


# project 7x7 fisher to b,f,s,1/n 
datav_b = np.zeros((3,6))
datav_b[0][0] = 1.
datav_b[1][1] = 1.
datav_b[2][2] = 1.
datav_b[0][3] = 1.
datav_b[1][4] = 1.
datav_b[2][5] = 1.   

Fb3x3= np.dot( np.dot(datav_b, Fa6x6), datav_b.T ) # <- b,f,s,1/n fisher
Cb3x3 = inv(Fb3x3)
print 'sum of second F', np.sum(Fb3x3)

print np.sqrt(C_p)[1][1]
print 'sigma_f', np.sqrt(Cb3x3[1][1])
print 'the ratio', np.sqrt(C_p)[1][1]/np.sqrt(Cb3x3[1][1])
# Out:
# sum of fist F 141236.907458
# sum of second F 141236.907458
# 0.0219508933749
# sigma_f 0.0140981243975
# the ratio 1.55700806405
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:34: RuntimeWarning: invalid value encountered in sqrt
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:36: RuntimeWarning: invalid value encountered in sqrt

# %%
# b,f
mask_sn_mar = np.ones((7,7), dtype=bool)
mask_sn_mar[:,2] = 0
mask_sn_mar[2,:] = 0
mask_sn_mar[:,3] = 0
mask_sn_mar[3,:] = 0
mask_sn_mar[:,-1] = 0
mask_sn_mar[-1,:] = 0

Ca4x4=C_7x7[mask_sn_mar].reshape(4,4)
Fa4x4 = inv(Ca4x4)  # <- b,f,b,f fisher

datav_f = np.zeros((2,4))
datav_f[0][0] = 1
datav_f[1][1] = 1
datav_f[0][2] = 1
datav_f[1][3] = 1

Ff2x2= np.dot( np.dot(datav_f, Fa4x4), datav_f.T ) # <- b,f,s,1/n fisher
Cf2x2 = inv(Ff2x2)
print 'sigma_f', np.sqrt(Cf2x2[1][1])
print 'the ratio', np.sqrt(C_p)[1][1]/np.sqrt(C_7x7[1][1])
# Out:
# sigma_f 0.0140998460125
# the ratio 1.54967217698
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:22: RuntimeWarning: invalid value encountered in sqrt

# %%
# f
mask_fsn_mar = np.ones((7,7), dtype=bool)
mask_fsn_mar[:,0] = 0
mask_fsn_mar[0,:] = 0
mask_fsn_mar[:,2] = 0
mask_fsn_mar[2,:] = 0
mask_fsn_mar[:,3] = 0
mask_fsn_mar[3,:] = 0
mask_fsn_mar[:,4] = 0
mask_fsn_mar[4,:] = 0
mask_fsn_mar[:,6] = 0
mask_fsn_mar[6,:] = 0
Ca2x2 = C_7x7[mask_fsn_mar].reshape(2,2)
Fa2x2 = inv(Ca2x2)  # <- b,f,b,f fisher


print 'sum of first F', np.sum(Fa2x2)


# project 7x7 fisher to b,f,s,1/n 
datav_f = np.ones((1,2)) 

Ff1x1= np.dot( np.dot(datav_f, Fa2x2), datav_f.T ) # <- b,f,s,1/n fisher
print 'sum of second F', np.sum(Ff1x1)
print 'sigma_f', np.sqrt(1./Ff1x1[0][0])
print 'the ratio', np.sqrt(C_p)[1][1]/np.sqrt(1./Ff1x1[0][0])
# Out:
# sum of first F 4984.63929218
# sum of second F 4984.63929218
# sigma_f 0.0141639091264
# the ratio 1.54977649031
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:26: RuntimeWarning: invalid value encountered in sqrt

# %%
# b,f,s
sigma_f 0.0140981243975
the ratio 1.55700806405

# b,f
sigma_f 0.0140998460125
the ratio 1.54967217698

# f
sigma_f 0.0141639091264
the ratio 1.54977649031
# Out:
#   File "<ipython-input-794-c6e974e2fc77>", line 2
#     sigma_f 0.0140981243975
#                           ^
# SyntaxError: invalid syntax

# %%
fisher_param = np.genfromtxt('data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt')
C_p = inv(fisher_param[:,1].reshape(4,4))
C_tot = inv(fisher_param[:,3].reshape(4,4))

# %%
C_p
# Out:
# array([[  9.49793253e-05,  -1.59367034e-04,  -4.74866545e-03,
#          -5.35642021e-01],
#        [ -1.59367034e-04,   4.81841720e-04,   1.39720608e-02,
#           8.64302707e-01],
#        [ -4.74866545e-03,   1.39720608e-02,   5.01739540e-01,
#           3.10863128e+01],
#        [ -5.35642021e-01,   8.64302707e-01,   3.10863128e+01,
#           3.61527482e+03]])

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs = 'data_txt/test_bfs_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfsn = 'data_txt/test_bfsn_k0_02_kN200_r18_180_rN162_fisher_params.txt'
text_label = '   k = [0,0.2] h/Mpc (test) \n   r = [18,180] Mpc/h (Sanchez)\n'
plot_triple_ellipse([bfsn], parameter_name = [r'$b$', r'$f$', r'$\sigma_v$']\
                 , linecolor = ['b', 'r', 'g', 'y' ,'b', 'r', 'g', 'y', 'c', 'k']
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid']
                 , parameter_truth = [2.0, 0.74, 3.5], diffsky=1, dnn=0
                 , keeps = [[0,1], [0,2], [1,2]]
                 , extent =[[0.95, 1.055], [0.7, 1.3], [-1, 3], [0.95, 1.05],[0.85, 1.15],[0.75, 1.25]]
                 , text_label = text_label, out_name = 'figure/ellipse_test_bfsn_k0_02_kN500_r18_180_rN162.png')
text_label = '   k = [0,0.2] h/Mpc \n   r = [20,160] Mpc/h (Sanchez)\n'

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfsn = 'data_txt/test_bfsn_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
text_label = '   k = [0,0.2] h/Mpc (test) \n   r = [18,180] Mpc/h (Sanchez)\n'
plot_triple_ellipse([bfsn]
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_v$', r'1/n']\
                 , linecolor = ['b', 'r', 'g', 'y' ,'b', 'r', 'g', 'y', 'c', 'k']
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid']
                 , parameter_truth = [2.0, 0.74, 3.5, 1e+4/3.], diffsky=1, dnn=0
                 , keeps = [[0,1], [0,2], [1,2],[0,3], [1,3], [2,3]]
                 , extent =[[0.95, 1.055], [0.7, 1.3], [-1, 3], [0.7, 1.3],[0.85, 1.15],[0.75, 1.25]]
                 , text_label = text_label, out_name = 'figure/ellipse_test_bfsn_k0_02_kN500_r18_180_rN162.png')
text_label = '   k = [0,0.2] h/Mpc \n   r = [20,160] Mpc/h (Sanchez)\n'

# %%
bfsn = 'data_txt/default_kN500_ke-3_rN180_re-3_bfsn_fisher_params_nn.txt'
#bfsn = 'data_txt/test_bfsn_k0_025_kN500_r14_180_rN157_fisher_params_nn.txt'
text_label = '   k = [0,0.2] h/Mpc (test) \n   r = [18,180] Mpc/h (Sanchez)\n'
plot_triple_ellipse([bfsn]
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_v$', r'1/n']\
                 , linecolor = ['b', 'r', 'g', 'y' ,'b', 'r', 'g', 'y', 'c', 'k']
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid']
                 , parameter_truth = [2.0, 0.74, 3.5, 1./0.0003], diffsky=1, dnn=0
                 , keeps = [[0,1], [0,2], [1,2],[0,3], [1,3], [2,3]]
                 , extent =[[0.995, 1.005], [0.95, 1.05], [0.7, 1.3], [0.9995, 1.0005]]
                 , text_label = text_label, out_name = 'figure/ellipse_test_bfsn_k0_02_kN500_r18_180_rN162.png')
text_label = '   k = [0,0.2] h/Mpc \n   r = [20,160] Mpc/h (Sanchez)\n'

# %%
bfsn = 'data_txt/test_bfsn_k0_02_kN200_r18_180_rN162_fisher_params_nn.txt'
#bfsn = 'data_txt/test_bfsn_k0_025_kN500_r14_180_rN157_fisher_params_nn.txt'
text_label = '   k = [0,0.2] h/Mpc (test) \n   r = [18,180] Mpc/h (Sanchez)\n'
plot_triple_ellipse([bfsn]
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_v$', r'1/n']\
                 , linecolor = ['b', 'r', 'g', 'y' ,'b', 'r', 'g', 'y', 'c', 'k']
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid']
                 , parameter_truth = [2.0, 0.74, 3.5, 1./0.0003], diffsky=1, dnn=0
                 , keeps = [[0,1], [0,2], [1,2],[0,3], [1,3], [2,3]]
                 , extent =[[0.995, 1.005], [0.95, 1.05], [0.7, 1.3], [0.995, 1.005]]
                 , text_label = text_label, out_name = 'figure/ellipse_test_bfsn_k0_02_kN500_r18_180_rN162.png')
text_label = '   k = [0,0.2] h/Mpc \n   r = [20,160] Mpc/h (Sanchez)\n'

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bf = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params.txt'
# TEST 2
text_label = '   k = [0,0.2] h/Mpc  \n   r = [20,160] Mpc/h (Sanchez)\n'
plot_single_ellipse([bf]
                 , linestyle = ['solid', 'solid', 'solid']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v,p}$', r'\bar{n}',r'$b$', r'$f$', r'$\sigma_{v,\xi}$']\
                 , parameter_truth = [2.0, 0.74], keep = [0,1]\
                 , extent =[[0.975, 1.025], [0.85, 1.15]]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')
# Out:
# cov_tot_keeped_matrix
# [[  1.55310800e-05  -2.73249374e-05]
#  [ -2.73249374e-05   9.27573035e-05]]

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs= 'data_txt/default_kN200_ke-3_rN180_re-3_bfs_p02_fisher_params_nn.txt'
bfsn= 'data_txt/default_kN200_ke-3_rN180_re-3_bfsn_p02_fisher_params_nn.txt'
# TEST 2
text_label = '/n'
plot_triple_ellipse([bfs, bfsn]
                 #, linestyle = ['solid', 'solid', 'solid']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.99, 1.01],[0.995, 1.005] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
#bfs= 'data_txt/test_bfs_k0_02_kN200_r18_180_rN162_p02_fisher_params_nn.txt'
bfsn= 'data_txt/test_bfsn_k0_02_kN200_r18_180_rN162_fisher_params_nn.txt'
# TEST 2
text_label = '/n'
plot_triple_ellipse([bfsn]
                 #, linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed']
                 #, linecolor = ['b', 'r', 'g', 'b', 'r', 'g', 'y', 'c', 'k']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$', '$n$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 , keeps = [[0,1], [0,2], [1,2],[0,3], [1,3], [2,3]]\
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.9, 1.1], [0.9, 1.1]]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs= 'data_txt/test_bfs_k0_02_kN200_r18_180_rN162_fisher_params_nn.txt'
bfsn= 'data_txt/test_bfsn_k0_02_kN200_r18_180_rN162_fisher_params_nn.txt'
# TEST 2
text_label = '/n'
plot_triple_ellipse([bfs, bfsn]
                 #, linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed']
                 #, linecolor = ['b', 'r', 'g', 'b', 'r', 'g', 'y', 'c', 'k']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.9, 1.1] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs= 'data_txt/test_bfs_k0_02_kN200_r18_180_rN162_p02_fisher_params_nn.txt'
bfsn= 'data_txt/test_bfsn_k0_02_kN200_r18_180_rN162_p02_fisher_params_nn.txt'
# TEST 2
text_label = '/n'
plot_triple_ellipse([bfs]
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed']
                 , linecolor = ['b', 'r', 'g', 'b', 'r', 'g', 'y', 'c', 'k']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.95, 1.05],[0.995, 1.005] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs= 'data_txt/test_bfs_k0_02_kN200_r18_180_rN162_p0_fisher_params_nn.txt'
# TEST 2
text_label = ''
plot_triple_ellipse([bfs]
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed']
                 , linecolor = ['b', 'r', 'g', 'b', 'r', 'g', 'y', 'c', 'k']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.95, 1.05],[0.995, 1.005] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs='data_txt/default_kN200_ke-3_rN180_re-3_bfs_p02_fisher_params_nn.txt'
# TEST 2
text_label = ''
plot_triple_ellipse([bfs]
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed']
                 , linecolor = ['b', 'r', 'g', 'b', 'r', 'g', 'y', 'c', 'k']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.99, 1.01],[0.9999, 1.0001] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs='data_txt/default_kN200_ke-3_rN180_re-3_bfs_p02_numeric_fisher_params_nn.txt'
# TEST 2
text_label = ''
plot_triple_ellipse([bfs]
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed']
                 , linecolor = ['b', 'r', 'g', 'b', 'r', 'g', 'y', 'c', 'k']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.99, 1.01],[0.9999, 1.0001] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs='data_txt/default_kN200_ke-3_rN180_re-3_bf_p02_fisher_params_nn.txt'
# TEST 2
text_label = ''
plot_single_ellipse([bfs]
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed']
                 , linecolor = ['b', 'r', 'g', 'b', 'r', 'g', 'y', 'c', 'k']
                 , parameter_name = [r'$b$', r'$f$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 #, keeps = [[0,1]]
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.99, 1.01],[0.9999, 1.0001] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')
# Out:
# cov_tot_keeped_matrix
# [[  4.13297131e-06  -8.20521829e-06]
#  [ -8.20521829e-06   3.68801223e-05]]

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs='data_txt/default_kN200_ke-3_rN180_re-3_bfs_p02_fisher_params_nn.txt'
# TEST 2
text_label = '/n'
plot_triple_ellipse([bfs]
                 , linestyle = ['solid', 'solid', 'solid', 'dashed', 'dashed', 'dashed']
                 , linecolor = ['b', 'r', 'g', 'b', 'r', 'g', 'y', 'c', 'k']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.99, 1.01],[0.9999, 1.0001] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs= 'data_txt/default_kN200_ke-3_rN180_re-3_bfsn_p02_fisher_params_nn.txt'
# TEST 2
text_label = '/n'
plot_triple_ellipse([bfs]
                 , linestyle = ['solid', 'solid', 'solid']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$', r'$n$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 , keeps = [[0,1], [0,2], [1,2],[0,3], [1,3], [2,3]]
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.99, 1.01], [0.9999, 1.0001] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfs= 'data_txt/test_bfsn_k0_02_kN200_r18_180_rN162_fisher_params.txt'
# TEST 2
text_label = '/n'
plot_triple_ellipse([bfs]
                 , linestyle = ['solid', 'solid', 'solid']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$', r'$n$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 , keeps = [[0,1], [0,2], [1,2],[0,3], [1,3], [2,3]]
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.95, 1.05],[0.95, 1.05] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
#bfsn_nn = 'data_txt/test_bf_k0_02_kN500_r18_180_rN162_fisher_params_nn.txt'
bfsn02= 'data_txt/test_bfsn_k0_02_kN200_r18_180_rN162_p02_fisher_params_nn.txt'
bfsn= 'data_txt/test_bfsn_k0_02_kN200_r18_180_rN162_fisher_params_nn.txt'
# TEST 2
text_label = '/n'
plot_triple_ellipse([bfs02, bfs]
                 #, linestyle = ['solid', 'solid', 'solid']
                 , parameter_name = [r'$b$', r'$f$', r'$\sigma_{v}$', r'$n$']\
                 , parameter_truth = [2.0, 0.74, 3.5, 0.0003]\
                 , keeps = [[0,1], [0,2], [1,2],[0,3], [1,3], [2,3]]
                 , extent =[[0.99, 1.01], [0.95, 1.05],[0.95, 1.05],[0.93, 1.07] ]
                 , text_label = text_label, out_name = 'figure/ellipse_test.png')

# %%
params_p_datav = np.genfromtxt('data_txt/datav/default_kN200_ke-3_rN180_re-3_bfs_p02_params.datavector')[2,:]
kcenter = np.genfromtxt('data_txt/kcenter.txt')

# %%
params_p_datav0 = params_p_datav[:kcenter.size]
params_p_datav2 = params_p_datav[kcenter.size:kcenter.size*2]
params_p_datav4 = params_p_datav[2*kcenter.size:]

# %%
# last term, shell avg
fig, ax = plt.subplots()
ax.plot(kcenter, params_p_datav0)
ax.legend()
ax.set_ylabel(r'$dP/d\sigma_v$')
ax.set_xlabel(r'$r$')
ax.set_xlim(0, 0.5)
# Out:
# (0, 0.5)
