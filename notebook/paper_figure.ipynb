# %%
import numpy as np
from numpy import zeros, sqrt, pi, vectorize
from numpy.linalg import pinv, inv
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
rootdir = '/n/des/lee.5922/Dropbox/repositories/bandpower/SNR/output_demo/'

# %%
ls /n/des/lee.5922/Dropbox/repositories/bandpower/SNR/output_demo/
# Out:
# bandpowerP_fisher.txt     DXi_datavector.txt      PXi.cov      Xi.cov
# bandpower_tot_fisher.txt  fishertot.fisher        rcenter.txt  Xi_fisher.txt
# bandpowerXi_fisher.txt    kcenter.txt             snr_p
# DP_datavector.txt         multipole_p.datavector  snr_tot
# DP_params_datavector.txt  P.cov                   snr_xi

# %%
kbin, snrp = np.genfromtxt(rootdir + 'snr_p', unpack=True)
kbin2, snrxi = np.genfromtxt(rootdir + 'snr_xi', unpack=True)
kbin3, snrtot = np.genfromtxt(rootdir + 'snr_tot', unpack=True)
print snrp.size, snrxi.size, snrtot.size
# Out:
# 50 499 499

# %%
fig, ax = plt.subplots(figsize = (10,10))
ax.plot(kbin, snrp, 'k-')
ax.plot(kbin2, snrxi, '--')
ax.plot(kbin3, snrtot, '--')

#ax.set_ylim(0,10000000 )
