# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import sys
sys.path.append('../')
sys.path.append('../src/')
#sys.path.append('/n/des/lee.5922/programs/cosmolike/MG_musigma/')
from discrete import *
from noshellavg_v2 import *
#from mock_test import *
#from run_error_analysis import *
#from plot_chain import plot_single, plot_triple, plot_distributions, plot_summary_bar
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def generate_mocks( cosmo, kbin, p_model, covp_model, N_mock = 500 ):
    print 'generate mocks... size=', N_mock
    p_mock = np.array([np.random.normal(loc=p_model[i], scale=np.sqrt(covp_model.diagonal()[i]),
                                             size=N_mock) for i in range(kbin.size)]).T
    xi_mock = fourier_tr_xi_mock(cosmo, kbin, p_mock)
    return p_mock, xi_mock


def fourier_tr_xi_mock(cosmo, kbin, p_mock):
    xi_mock = []
    for i in range(len(p_mock)):
        xi_mock.append(cosmo.fourier_transform_kr(0, kbin, p_mock[i]))
        print 'fourier transform.. {}/{} \r'.format(i+1, len(p_mock)),
    xi_mock = np.array(xi_mock)
    return xi_mock

def mock_covariance(p_model, xi_model, p_mock, xi_mock):
    m1, m2 = np.mgrid[0:p_model.size, 0:xi_model.size]
    mock_covpxi = np.zeros(( p_model.size, xi_model.size ))
    for i in range(len(p_mock)) :
        p = p_mock[i]
        x = xi_mock[i]
        mock_covpxi += ( p[m1] - p_model[m1]) * (x[m2] - xi_model[m2])
        print '{}/{}                \r'.format(i+1, len(p_mock)),
    mock_covpxi = 1./( len(p_mock) - 1 ) * mock_covpxi
    
    #if p_model.size == xi_model.size : mock_covpxi = (mock_covpxi + mock_covpxi.T)/2.
    return mock_covpxi


def datavector_bias_2d_interp(cosmo):

    blist = np.linspace(0.5, 3.5, 51)
    print 'Calculate datavector p(b) and xi(b) for b = [{},{}]'.format(blist[0], blist[-1])
    datavlist = []
    datavlist_xi = []
    i=0
    for bb in blist:
        datavp, datavxi = compute_data_vector(cosmo, b=bb, s = 0)
        datavlist.append(datavp)
        datavlist_xi.append(datavxi)
        print '{:0.2f}  {}/{}                   \r'.format(bb, i+1, len(blist)),
        i+=1

    datavlist = np.array(datavlist)
    datavlist_xi = np.array(datavlist_xi)

    #print datavlist.shape, datavlist_xi.shape
    #datavlist_com = np.hstack((datavlist, datavlist_xi  ))
    print 'generate 2D interpolation table'
    datavp_interp = interp_2d( cosmo.kcenter_y, blist, datavlist )
    datavxi_interp = interp_2d( cosmo.rcenter[::-1], blist, datavlist_xi )

    cosmo.b = 2.0
    return datavp_interp, datavxi_interp


def getting_sigma_bs_theory( cosmo, b = None, cov = None, datavs = None, 
                     mockdatavs = None, p=False, kmin=None, kmax = None,
                     rmin = None, rmax = None):
    
    
    if kmin == None : 
        idx_kmin = 0
        idx_kmax = cosmo.kcenter_y.size
    else : 
        idx_kmin = get_closest_index_in_data( kmin, cosmo.kmin_y )   
        idx_kmax = get_closest_index_in_data( kmax, cosmo.kmax_y )
    
    if rmin == None : 
        idx_rmin = cosmo.rmax.size
        idx_rmax = 0
    else : 
        idx_rmin = get_closest_index_in_data( rmin, cosmo.rmin )   
        idx_rmax = get_closest_index_in_data( rmax, cosmo.rmax )
        
    mask = np.zeros(cov.shape[0], dtype=bool)
    if p : mask[idx_kmin:idx_kmax+1] = 1
    else : mask[idx_rmax:idx_rmin+1] = 1
        
    Nk = np.sum(mask)
    m1, m2 = np.mgrid[0:cov.shape[0],0:cov.shape[0]]
    mask_2d = mask[m1] * mask[m2]
           
    if p :print 'Nk ', Nk, ' kmin', idx_kmin, ' kmax', idx_kmax
    else : print 'Nr ', Nk, ' rmin', idx_rmin, ' rmax', idx_rmax
    
    covinv = np.linalg.inv(cov[mask_2d].reshape(Nk,Nk))
    
    #if p :dqdb = cosmo.dPdb0_interp(cosmo.kbin)
    #else :dqdb = cosmo.dxidb
    dqdb = datavs[mask]
    
    sigma_theory = 1./np.sqrt(np.dot( np.dot( dqdb, covinv ), dqdb.T))
    print ' theory :', sigma_theory
    return sigma_theory

def getting_sigma_bs_com_theory( cosmo, b = None, cov = None, datavp = None, datavx=None, 
                                 mockdatavs = None, p=False, 
                                 kmin=None, kmax = None, rmin=None, rmax = None ):
    
    if kmin == None : 
        idx_kmin = 0
        idx_kmax = cosmo.kcenter_y.size
    else : 
        idx_kmin = get_closest_index_in_data( kmin, cosmo.kmin_y )   
        idx_kmax = get_closest_index_in_data( kmax, cosmo.kmax_y )
        
    if rmin == None : 
        idx_rmin = cosmo.rmax.size
        idx_rmax = 0
    else : 
        idx_rmin = get_closest_index_in_data( rmin, cosmo.rmin )   
        idx_rmax = get_closest_index_in_data( rmax, cosmo.rmax )
        
        
    maskp = np.zeros(cosmo.kcenter_y.size, dtype=bool)
    maskp[idx_kmin:idx_kmax+1] = 1
    maskxi = np.zeros(cosmo.rcenter.size, dtype=bool)
    maskxi[idx_rmax:idx_rmin+1] = 1
    
    #print'maskp, maskxi', maskp.size, maskxi.size
    #print 'kcenter_Y', cosmo.kcenter_y.size
    mask = np.hstack([maskp, maskxi])
    Nk = np.sum(mask)
    #print mask.size, cov.shape[0]
    m1, m2 = np.mgrid[0:cov.shape[0],0:cov.shape[0]]
    #print m1.size
    mask_2d = mask[m1] * mask[m2]
    
    print 'N ', Nk, ' kmin', idx_kmin, ' kmax', idx_kmax, ' rmin', idx_rmin, ' rmax', idx_rmax
    
    #covinv = np.linalg.inv(cov[mask_2d].reshape(Nk, Nk))
    covp = cov[idx_kmin:idx_kmax+1, idx_kmin:idx_kmax+1]
    covxi = cov[cosmo.kcenter_y.size + idx_rmax:cosmo.kcenter_y.size+idx_rmin+1,\
                cosmo.kcenter_y.size + idx_rmax:cosmo.kcenter_y.size+idx_rmin+1]
    covpxi = cov[idx_kmin:idx_kmax+1,\
                cosmo.kcenter_y.size + idx_rmax:cosmo.kcenter_y.size+idx_rmin+1]
    
    #covinv = invert_covtot(covp ,covxi, covpxi)
    covtot = np.vstack(( np.hstack((covp, covpxi )), np.hstack((covpxi.T, covxi )) ))
    covinv = np.linalg.inv(covtot)
    #print covinv.diagonal
    #print 'covp', covp
    #print 'covxi', covxi
    print 'Warning : negative diagonal ', np.sum( covinv.diagonal() < 0)    
    
    #datavp = datavp[idx_kmin:idx_kmax+1]
    #datavx = datavx
    dqdb = np.hstack((datavp, datavx))[mask]    
    sigma_theory = 1./np.sqrt(np.dot( np.dot( dqdb, covinv), dqdb.T))
    print ' theory :', sigma_theory
    return sigma_theory


def getting_sigma_bs_diff_theory( cosmo, b = None, covp = None, covxi = None, 
                          datavp = None, datavx = None, 
                          mockdatavsp = None, mockdatavsxi = None, p=False, 
                          kmin=None, kmax = None,
                          rmin = None, rmax = None):
 
    if kmin == None : 
        idx_kmin = 0
        idx_kmax = cosmo.kbin.size
    else : 
        idx_kmin = get_closest_index_in_data( kmin, cosmo.kmin_y )   
        idx_kmax = get_closest_index_in_data( kmax, cosmo.kmax_y )
        
    if rmin == None : 
        idx_rmin = cosmo.rmax.size
        idx_rmax = 0
    else : 
        idx_rmin = get_closest_index_in_data( rmin, cosmo.rmin )   
        idx_rmax = get_closest_index_in_data( rmax, cosmo.rmax )

        
    maskp = np.zeros(cosmo.kcenter_y.size, dtype=bool)
    maskp[idx_kmin:idx_kmax+1] = 1
    maskxi = np.zeros(cosmo.rcenter.size, dtype=bool)   
    maskxi[idx_rmax:idx_rmin+1] = 1
    Nk, Nr = np.sum(maskp), np.sum(maskxi) 
        
    m1, m2 = np.mgrid[0:covp.shape[0],0:covp.shape[0]]
    maskp_2d = maskp[m1] * maskp[m1].T
    m1, m2 = np.mgrid[0:covxi.shape[0],0:covxi.shape[0]]
    maskxi_2d = maskxi[m1] * maskxi[m1].T    
    
    print 'Nk ', Nk, ' kmin', idx_kmin, ' kmax', idx_kmax
    print 'Nr ', Nr, ' rmin', idx_rmin, ' rmax', idx_rmax
    
    
    covinv_p = np.linalg.inv(covp[maskp_2d].reshape(Nk, Nk))
    covinv_xi = np.linalg.inv(covxi[maskxi_2d].reshape(Nr, Nr))
    
    dpdb = datavp[maskp] #cosmo.dPdb0_interp(cosmo.kbin)[maskp]
    dxdb = datavx[maskxi] #cosmo.dxidb[maskxi]

    
    Fp = np.dot( np.dot(dpdb, covinv_p), dpdb.T)
    Fx = np.dot( np.dot(dxdb, covinv_xi), dxdb.T)
    
    sigma_theory = 1./np.sqrt((Fp+Fx))
    print ' theory :', sigma_theory
    return sigma_theory

# %% [markdown]
# ## Initialize Class, Calculate datavector and cov matrices

# %% [markdown]
# No Shotnoise, No Finger of God term

# %%
b = 2 #galaxy bias
f = 0.74 #structure growth rate
s = 3.5 #3.5 #velocity dispersion in FoG term 
nn = 3.0e-04 #shot noise 3.0e-04

cosmo = class_discrete_covariance(KMIN=0.0001, KMAX = 10, n=20000, RMIN = 40, RMAX = 200, n_y=500, n2 = 40, \
                     b=b, f=f, s=s, nn=nn, rscale = 'lin', kscale='log')
cosmo2 = class_discrete_covariance(KMIN=0.0001, KMAX = 10, n=20000, RMIN = 40, RMAX = 180, n_y=500, n2 = 40, \
                     b=b, f=f, s=0, nn=nn, rscale = 'lin', kscale='log')

# %%
#cosmo.compile_fortran_modules()
# calling matter power spectrum from camb
cosmo.MatterPower()

#cosmo.multipole_P_band_all()

p_model = cosmo.multipole_P(0)
#shell_p_model = cosmo.shellavg_k(cosmo.kbin, p_model)
#shell_p_model_SN = shell_p_model # + 1./cosmo.nn
#p_model = cosmo.Pmultipole0_interp(cosmo.kbin)
xi_model = cosmo.multipole_Xi(0)
#xi_model_ = cosmo._multipole_Xi(0)

covp_model = cosmo.covariance_PP(0,0)
covxi_model = cosmo.covariance_Xi(0,0) 

covpxi_model = cosmo.covariance_PXi(0,0)
#covpxi_model_ = cosmo._covariance_PXi(0,0) 

covtot_model = np.vstack(( np.hstack((covp_model, covpxi_model )), \
                          np.hstack((covpxi_model.T, covxi_model )) ))

dpdb,_,_ = cosmo.derivative_P_bfs(0)      # dp/db
dxdb,_,_ = cosmo.derivative_bfs(0)

# %%
#datavp_interp, datavxi_interp = datavector_bias_2d_interp(cosmo)
#cosmo.b = 2.0

# %%
# interpolate
bbin = np.linspace(0.5, 3.5, 20000)
datav_p = datavp_interp(cosmo.kcenter_y, bbin)
datav_xi = datavxi_interp(cosmo.rcenter, bbin)
datav_com = np.hstack((datav_p, datav_xi))

# %%
kmin = 0.01
kmax = 0.2
#rmin = 0
#rmax = 180

# %%
sigma_p = getting_sigma_bs_theory( cosmo, b = bbin, cov = covp_model, datavs = dpdb, 
                                     mockdatavs = p_mock, p=True, kmin=kmin, kmax=kmax )
sigma_x = getting_sigma_bs_theory( cosmo, b = bbin, cov = covxi_model, datavs = dxdb, 
                                     mockdatavs = xi_mock, rmin = None, rmax=None )
sigma_d = getting_sigma_bs_diff_theory( cosmo, b = bbin, covp = covp_model, covxi = covxi_model, 
                          datavp = dpdb, datavx = dxdb, 
                          mockdatavsp = p_mock, mockdatavsxi = xi_mock, kmin=kmin, kmax=kmax, rmin=None, rmax=None )
sigma_c = getting_sigma_bs_com_theory( cosmo, b = bbin, cov = covtot_model, 
                                     datavp = dpdb, datavx=dxdb, mockdatavs = None,
                                     kmin = kmin, kmax = kmax, rmin=None, rmax=None)

# print out results-------------------------------
print '---------------------------------\
\n Error on bias (Theory) \n sigma_p      : {} \n sigma_xi     : {} \n sigma_combin : {} \n sigma_diff   : {} \
\n---------------------------------'.format(sigma_p, sigma_x, sigma_c, sigma_d)
# Out:
# Nk  130  kmin 200  kmax 329
#  theory : 0.0028334918356332514
# Nr  40  rmin 40  rmax 0
#  theory : 0.02597415892038154
# Nk  130  kmin 200  kmax 329
# Nr  40  rmin 40  rmax 0
#  theory : 0.0028167810181925273
# N  170  kmin 200  kmax 329  rmin 40  rmax 0
# Warning : negative diagonal  0
#  theory : 0.002816811626027524
# ---------------------------------
#  Error on bias (Theory)
#  sigma_p      : 0.00283349183563
#  sigma_xi     : 0.0259741589204
#  sigma_combin : 0.00281681162603
#  sigma_diff   : 0.00281678101819
# ---------------------------------

# %%
fig, ax = plt.subplots()
#ax.loglog( cosmo.kcenter_y, covp_model)

ax.loglog( cosmo.kbin, cosmo.covP00_interp(kbin), label='continuous')
ax.loglog( cosmo.kcenter_y, covp_model.diagonal(), label = 'model')
#ax.loglog( cosmo.kcenter_y, mock_covp.diagonal(), '--', label = 'mock')
ax.legend()



fig, ax = plt.subplots()
#ax.loglog( cosmo.kcenter_y, covp_model)

#ax.loglog( cosmo.rcenter, cosmo.covP00_interp(kbin), label='continuous')
ax.loglog( cosmo.rcenter, covxi_model.diagonal(), label = 'model')
#ax.loglog( cosmo.rcenter, mock_covxi.diagonal(), '--', label = 'mock')

ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1134-85df2e9d65d6> in <module>()
#       2 #ax.loglog( cosmo.kcenter_y, covp_model)
#       3
# ----> 4 ax.loglog( cosmo.kbin, cosmo.covP00_interp(kbin), label='continuous')
#       5 ax.loglog( cosmo.kcenter_y, covp_model.diagonal(), label = 'model')
#       6 #ax.loglog( cosmo.kcenter_y, mock_covp.diagonal(), '--', label = 'mock')
#
# /home/lee.5922/.local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in loglog(self, *args, **kwargs)
#    1541         b = self._hold
#    1542         self._hold = True  # we've already processed the hold
# -> 1543         l = self.plot(*args, **kwargs)
#    1544         self._hold = b  # restore the hold
#    1545
#
# /home/lee.5922/.local/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /home/lee.5922/.local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# /home/lee.5922/.local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# /home/lee.5922/.local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# /home/lee.5922/.local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _xy_from_xy(self, x, y)
#     242         if x.shape[0] != y.shape[0]:
#     243             raise ValueError("x and y must have same first dimension, but "
# --> 244                              "have shapes {} and {}".format(x.shape, y.shape))
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (20001,) and (10001,)

# %%
fig, ax = plt.subplots()
#ax.plot( cosmo.kbin, covpxi_model[:,0], label = 'old')
ax.plot( cosmo.kcenter_y, covpxi_model[:,0], label = 'model')
#ax.plot( cosmo.kcenter_y, mock_covpxi[:,0], '-', label = 'mock', alpha= 0.3)
ax.set_yscale('linear')
ax.set_xscale('log')
ax.legend()

fig, ax = plt.subplots()
ax.plot( cosmo.rcenter, covpxi_model[0, :], label='old')
#ax.plot( cosmo.rcenter, covpxi_model_[0, :], label='model')
#ax.plot( cosmo.rcenter, mock_covpxi[0, :], '-', label = 'mock', alpha= 0.3)
ax.set_yscale('linear')
ax.set_xscale('log')

# %%
kbin = cosmo.kbin
p = p_model
shell_p = cosmo.shellavg_k(kbin, p)

covp = cosmo.covP00_interp(kbin)
shell_covp = cosmo.shellavg_k(kbin, covp)

# %%
fig, ax = plt.subplots()
ax.plot( cosmo.kbin, covpxi_model[:,5])
ax.plot( cosmo.kcenter_y, covpxi_model_[:,5])
ax.set_yscale('linear')
ax.set_xscale('log')

# %%
fig, ax = plt.subplots()
ax.plot( cosmo.rcenter, covpxi_model[-1,:])
ax.plot( cosmo.rcenter, covpxi_model_[-1,:])
ax.set_yscale('linear')
ax.set_xscale('linear')

# %%
fig, ax = plt.subplots()
ax.loglog( cosmo.rcenter, covxi_model.diagonal())
ax.loglog( cosmo2.rcenter, covxi_model2.diagonal())
ax.set_xscale('linear')

# %%
fig, ax = plt.subplots()
#ax.loglog( cosmo.kcenter_y, covp_model)

ax.loglog( cosmo.kbin, cosmo.covP00_interp(kbin), label='continuous')
ax.loglog( cosmo.kcenter_y, shell_covp, label = 'avg')
ax.loglog( cosmo.kcenter_y, covp_model_.diagonal())

ax.legend()

# %%
fig, ax = plt.subplots()
#ax.loglog( cosmo.kcenter_y, covp_model)

ax.loglog( cosmo.kbin, cosmo.covP00_interp(kbin), label='continuous')
ax.loglog( cosmo.kcenter_y, shell_covp, label = 'avg')
ax.loglog( cosmo.kcenter_y, covp_model_.diagonal())

ax.legend()

# %%
fig, ax = plt.subplots()
#ax.loglog( kbin, p - 1./cosmo.nn )
ax.loglog( cosmo.kcenter_y, shell_p)
ax.loglog( cosmo.kbin, p_model)
ax.loglog( cosmo.kbin, p_model - 1./cosmo.nn)

# %%
xi_model_ = cosmo.fourier_transform_kr(0, kbin, p_model-1./cosmo.nn)
# Out:
# correct

# %%
fig, ax = plt.subplots()
ax.plot( cosmo.rcenter, cosmo.rcenter**2 * xi_model)
ax.plot( cosmo.rcenter, cosmo.rcenter**2 * xi_model_)

# %%
cosmo2.kcenter_y
# Out:
# array([ 0.76604082,  1.6408426 ,  2.61907455,  3.6206054 ,  4.63037402,
#         5.64396308,  6.65962877,  7.67654695,  8.69427817,  9.71256686,
#        10.73125432, 11.75023684, 12.76944379, 13.7888254 , 14.80834561,
#        15.82797762, 16.84770114, 17.86750051, 18.88736343, 19.90728014,
#        20.92724277, 21.94724493, 22.96728134, 23.98734764, 25.00744017,
#        26.02755585, 27.04769204, 28.06784653, 29.08801738, 30.10820293,
#        31.12840174, 32.14861254, 33.16883423, 34.18906583, 35.20930648,
#        36.22955541, 37.24981195, 38.27007549, 39.29034547, 40.31062142,
#        41.33090289, 42.35118948, 43.37148084, 44.39177662, 45.41207653,
#        46.43238031, 47.4526877 , 48.47299847, 49.49331241])

# %%
kbinp, snrp = np.genfromtxt('../output_demo/snr_p.txt' ,unpack=True)
kbin, snrxi = np.genfromtxt('../output_demo/snr_xi.txt' ,unpack=True)
kbin, snrtot = np.genfromtxt('../output_demo/snr_tot.txt' ,unpack=True)


fig, ax = plt.subplots()
#ax.loglog( cosmo.kcenter_y, covp_model)
ax.plot(kbinp, snrp, label='p')
#ax.plot(kbin, snrxi, label='xi')
#ax.plot(kbin, snrtot, label='tot')
ax.legend()

#ax.set_xscale('log')

# %%
"""
 b = galaxy bias
 f = structure growth rate
 s = velocity dispersion in FoG term 
 nn = shot noise 
"""
cosmo = class_covariance(KMIN=0.001, KMAX = 100, n=5000, RMIN = 0.001, RMAX = 200, n2 = 101, \
                         b = 2.0, f = 0.74, s=0, nn=3.0e-04, rscale = 'lin', kscale='log')

#cosmo.compile_fortran_modules()

# copy class to keep initial setting
cosmo2 = cosmo
cosmo2.MatterPower()

# calling matter power spectrum from camb
cosmo.MatterPower()
p_model = cosmo.multipole_P(0)
xi_model = cosmo.multipole_Xi(0)

# calculate covariance matrix
covp_model = cosmo.covariance_PP(0,0)     # cov P monopole
covxi_model = cosmo.covariance_Xi(0,0)    # cov Xi monopole  : double bessel FT of covp_model
covpxi_model = cosmo.covariance_PXi(0,0)  # cov Pxi monopole : FT of covp_model
covtot_model = np.vstack(( np.hstack((covp_model, covpxi_model )), \
                          np.hstack((covpxi_model.T, covxi_model )) ))   # cov_combined
dpdb,_,_ = cosmo.derivative_P_bfs(0)      # dp/db
dxdb,_,_ = cosmo.derivative_bfs(0)        # dxi/db
dvdb = np.hstack((dpdb, dxdb))
# Out:
# cov xi 9999/10000

# %% [markdown]
# ## Generate Mocks

# %%
header = "class_covariance(KMIN=0.001, KMAX = 100, n=3000, RMIN = 0.001, RMAX = 200, n2 = 41, \
                         b = 2.0, f = 0.74, s=3.5, nn=3.0e-04, rscale = 'lin', kscale='lin')"
dirs = '../data_txt/mocks23/'
p_mock, xi_mock = generate_mocks( cosmo, p_model, covp_model, N_mock = 100 )
save_mocks( cosmo, p_mock, xi_mock, header = header, dir = dirs  )
kcenter, p_mock, rcenter, xi_mock = load_mocks(dir = dirs)
mocks = np.hstack(( p_mock, xi_mock ))
# Out:
# generate mocks... size= 100
# fourier transform.. 100/100

# %% [markdown]
# Mock Covariance matrices

# %%
mock_covpxi = mock_covariance(p_model, xi_model, p_mock, xi_mock)
mock_covp = mock_covariance(p_model, p_model, p_mock, p_mock)
mock_covxi = mock_covariance(xi_model, xi_model, xi_mock, xi_mock)
mock_covtot = np.vstack(( np.hstack((mock_covp, mock_covpxi )), np.hstack((mock_covpxi.T, mock_covxi )) ))
# Out:
# 100/100

# %% [markdown]
# ### Theory Datavector with varying bias

# %% [markdown]
# #### 2D Interpolation

# %%
datavp_interp, datavxi_interp = datavector_bias_2d_interp(cosmo)
cosmo.b = 2.0
# Out:
# Calculate datavector p(b) and xi(b) for b = [0.5,3.5]
# (51, 5000) (51, 100)
# generate 2D interpolation table

# %%
# interpolate
bbin = np.linspace(0.5, 3.5, 20000)
datav_p = datavp_interp(kcenter, bbin)
datav_xi = datavxi_interp(cosmo.rcenter, bbin)
datav_com = np.hstack((datav_p, datav_xi))

# %% [markdown]
# #### Mock, Theory data vectors

# %%
datav_p[0].shape, datav_p[-1].shape, kcenter.size
# Out:
# ((5000,), (5000,), 5000)

# %%
fig, ax = plt.subplots(figsize = (12,5))
#for i in range(100): 

for i in range(len(p_mock)) : ax.plot(kcenter, p_mock[i],  color='grey', alpha = 0.1)
ax.plot(kcenter, p_mock[-1], color='grey', alpha = 0.1, label = 'mocks')

ax.errorbar(kcenter, p_model, \
            yerr = np.sqrt(covp_model.diagonal()), fmt='', label = 'theory')

ax.fill_between(kcenter, datav_p[0], datav_p[-1], color = 'red', alpha = 0.1, label = 'varying b =[0.5,3.5]')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1e-02, 10)
ax.set_ylim(1e03, 1e06)
ax.legend(loc='best')
ax.set_ylabel(r'$P(k)$')
ax.set_xlabel(r'$k$')

fig, ax = plt.subplots(figsize = (12,5))
#for i in range(10): 
for i in range(len(xi_mock)) : ax.plot(cosmo.rcenter, cosmo.rcenter**2*xi_mock[i], color='grey', alpha = 0.1)
ax.plot(cosmo.rcenter, cosmo.rcenter**2*xi_mock[-1], color='grey', alpha = 0.1, label = 'mocks')
ax.errorbar(cosmo.rcenter, cosmo.rcenter**2*xi_model, \
            yerr = cosmo.rcenter**2*np.sqrt(covxi_model.diagonal()), fmt='',label = 'theory')
ax.fill_between(cosmo.rcenter, cosmo.rcenter**2* datav_xi[0], 
                cosmo.rcenter**2* datav_xi[-1], facecolor = 'red', alpha = 0.1, label = 'varying b=[0.5, 3.5]')
ax.set_ylim(-30, 120)
ax.set_ylabel(r'$r^2 \xi(r)$')
ax.set_xlabel(r'$r$')
ax.legend(loc='best')

# %% [markdown]
# #### Mock cov, Theoretical Cov

# %%
fig, (ax, ax2, ax3) = plt.subplots(1,3, figsize = (18,5))

ax.loglog(kcenter, covp_model.diagonal(), '-', linewidth = 4.0, label = 'cov model')
ax.loglog(kcenter, mock_covp.diagonal(), '-', label ='mock covp')
ax.set_xlabel('k')
ax.set_ylabel(r'$C_P (k,k)$')
ax.legend()

#fig, ax = plt.subplots()
ax2.plot(cosmo.rcenter, cosmo.rcenter**2*covxi_model.diagonal(), label='cov model')
ax2.plot(cosmo.rcenter, cosmo.rcenter**2*mock_covxi.diagonal(), '-', label = 'mock')
#ax.plot(cosmo.rcenter, cosmo.rcenter**2*cov_xi_3.diagonal(), '-', label = 'model2')
ax2.set_xlabel('r')
ax2.set_ylabel(r'$r^2 C_{\xi}(r,r)$')
ax2.legend()


#fig, ax = plt.subplots()
for i in np.arange(0, cosmo.rcenter.size, 30):
    ax3.plot(kcenter, mock_covpxi[:,i], alpha = 0.2)
    ax3.plot(kcenter, covpxi_model[:,i], label='r = {:0.2f}'.format(cosmo.rcenter[i]), color = ax3.lines[-1].get_color())
    
ax3.set_ylim(-5, 5)
ax3.set_xlim(1e-02,0.2)
ax3.set_xlabel('k')
ax3.set_ylabel(r'$C_{p\xi}(k,r)$')
ax3.set_xscale('log')
ax3.legend(loc='best')


fig, ((ax, ax2, ax3),(ax4, ax5, ax6)) = plt.subplots(2,3, figsize = (20,10))
im = ax.imshow(covp_model, vmax = 1e8, vmin = 0)
im2 = ax2.imshow(covxi_model, vmax=0.000001, vmin=-0.000001)
im3 = ax3.imshow(covpxi_model, aspect='auto', vmax=0.01, vmin=-0.01)

im4 = ax4.imshow(mock_covp, vmax = 1e8, vmin = 0)
im5 = ax5.imshow(mock_covxi, vmax=0.000001, vmin=-0.000001)
im6 = ax6.imshow(mock_covpxi, aspect='auto', vmax=0.01, vmin=-0.01)

fig.colorbar(im,ax=ax)
fig.colorbar(im2,ax=ax2)
fig.colorbar(im3,ax=ax3)
fig.colorbar(im4,ax=ax4)
fig.colorbar(im5,ax=ax5)
fig.colorbar(im6,ax=ax6)

# %% [markdown]
# ## Calcuate Bestfit Bias

# %% [markdown]
# Setting k range and r range

# %%
kmin = 0.01
kmax = 0.5
rmin = 10
rmax = 180

# %% [markdown]
# #### Theoretical calculation

# %%
sigma_p = getting_sigma_bs_theory( cosmo2, b = bbin, cov = covp_model, datavs = dpdb, 
                                     mockdatavs = None, p=True, kmin=kmin, kmax=kmax )
sigma_x = getting_sigma_bs_theory( cosmo2, b = bbin, cov = covxi_model, datavs = dxdb, 
                                     mockdatavs = None, rmin = rmin, rmax=rmax )
sigma_c = getting_sigma_bs_com_theory( cosmo2, b = bbin, cov = covtot_model, 
                                     datavs = dvdb, mockdatavs = None,
                                    kmin = kmin, kmax = kmax, rmin=rmin, rmax=rmax)
sigma_d = getting_sigma_bs_diff_theory( cosmo2, b = bbin, covp = covp_model, covxi = covxi_model, 
                          datavsp = dpdb, datavsxi = dxdb, 
                          mockdatavsp = None, mockdatavsxi = None, kmin=kmin, kmax=kmax, rmin=rmin, rmax=rmax )


# print out results-------------------------------
print '---------------------------------\
\n Error on bias (Theory) \n sigma_p      : {} \n sigma_xi     : {} \n sigma_combin : {} \n sigma_diff   : {} \
\n---------------------------------'.format(sigma_p, sigma_x, sigma_c, sigma_d)
# Out:
# Nk  1699  kmin 1000  kmax 2698
#  theory : 0.001377065436412227
# Nr  85  rmin 94  rmax 10
#  theory : 0.0038974082149789767
# N  1784  kmin 1000  kmax 2698  rmin 94  rmax 10
# Warning : negative diagonal  0
#  theory : 0.0012909615429417696
# Nk  1699  kmin 1000  kmax 2698
# Nr  85  rmin 94  rmax 10
#  theory : 0.0012984014805924172
# ---------------------------------
#  Error on bias (Theory)
#  sigma_p      : 0.00137706543641
#  sigma_xi     : 0.00389740821498
#  sigma_combin : 0.00129096154294
#  sigma_diff   : 0.00129840148059
# ---------------------------------

# %%
sigma_p = getting_sigma_bs_theory( cosmo2, b = bbin, cov = covp_model, datavs = dpdb, 
                                     mockdatavs = None, p=True, kmin=kmin, kmax=kmax )
sigma_x = getting_sigma_bs_theory( cosmo2, b = bbin, cov = covxi_model, datavs = dxdb, 
                                     mockdatavs = None, rmin = rmin, rmax=rmax )
sigma_c = getting_sigma_bs_com_theory( cosmo2, b = bbin, cov = covtot_model, 
                                     datavs = dvdb, mockdatavs = None,
                                    kmin = kmin, kmax = kmax, rmin=rmin, rmax=rmax)
sigma_d = getting_sigma_bs_diff_theory( cosmo2, b = bbin, covp = covp_model, covxi = covxi_model, 
                          datavsp = dpdb, datavsxi = dxdb, 
                          mockdatavsp = None, mockdatavsxi = None, kmin=kmin, kmax=kmax, rmin=rmin, rmax=rmax )


# print out results-------------------------------
print '---------------------------------\
\n Error on bias (Theory) \n sigma_p      : {} \n sigma_xi     : {} \n sigma_combin : {} \n sigma_diff   : {} \
\n---------------------------------'.format(sigma_p, sigma_x, sigma_c, sigma_d)
# Out:
# Nk  1699  kmin 1000  kmax 2698
#  theory : 0.001377065436412227
# Nr  85  rmin 94  rmax 10
#  theory : 0.0038974082149789767
# N  1784  kmin 1000  kmax 2698  rmin 94  rmax 10
# Warning : negative diagonal  0
#  theory : 0.0012909615429417696
# Nk  1699  kmin 1000  kmax 2698
# Nr  85  rmin 94  rmax 10
#  theory : 0.0012984014805924172
# ---------------------------------
#  Error on bias (Theory)
#  sigma_p      : 0.00137706543641
#  sigma_xi     : 0.00389740821498
#  sigma_combin : 0.00129096154294
#  sigma_diff   : 0.00129840148059
# ---------------------------------

# %% [markdown]
# #### Mock : Perform chisquare calculation to obtain bestfit biases with Cp, Cxi, Ctot, Cdiff

# %%
bestfit_b_p, chi2p = getting_sigma_bs( cosmo2, b = bbin, cov = covp_model, datavs = datav_p, 
                                     mockdatavs = p_mock, p=True, kmin=kmin, kmax=kmax )
# Out:
# Nk  1699  kmin 1000  kmax 2698
#  sigma_b : 0.00138997956801165
#  theory : 0.001377065436412227

# %%
bestfit_b_p, chi2p = getting_sigma_bs( cosmo2, b = bbin, cov = covp_model, datavs = datav_p, 
                                     mockdatavs = p_mock, p=True, kmin=kmin, kmax=kmax )
bestfit_b_xi, chi2x = getting_sigma_bs( cosmo2, b = bbin, cov = covxi_model, datavs = datav_xi, 
                                     mockdatavs = xi_mock, rmin = rmin, rmax=rmax )
bestfit_b_com, chi2_com = getting_sigma_bs_com( cosmo2, b = bbin, cov = covtot_model, 
                                     datavs = datav_com, mockdatavs = mocks,
                                    kmin = kmin, kmax = kmax, rmin=rmin, rmax=rmax)
bestfit_b_diff ,chi2_diff = getting_sigma_bs_diff( cosmo2, b = bbin, covp = covp_model, covxi = covxi_model, 
                          datavsp = datav_p, datavsxi = datav_xi, 
                          mockdatavsp = p_mock, mockdatavsxi = xi_mock, kmin=kmin, kmax=kmax, rmin=rmin, rmax=rmax )
# Out:
# Nk  1699  kmin 1000  kmax 2698
# 31/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-170-6593bf5031b4> in <module>()
#       1
#       2 bestfit_b_p, chi2p = getting_sigma_bs( cosmo2, b = bbin, cov = covp_model, datavs = datav_p,
# ----> 3                                      mockdatavs = p_mock, p=True, kmin=kmin, kmax=kmax )
#       4 bestfit_b_xi, chi2x = getting_sigma_bs( cosmo2, b = bbin, cov = covxi_model, datavs = datav_xi,
#       5                                      mockdatavs = xi_mock, rmin = rmin, rmax=rmax )
#
# /n/des/lee.5922/Dropbox/repositories/bandpower/SNR/mock_test.py in getting_sigma_bs(cosmo, b, cov, datavs, mockdatavs, p, kmin, kmax, rmin, rmax)
#     291             dv = datavs[j][mask]
#     292             #mv = mockdatavs[:,i][mask]
# --> 293             mv = mockdatavs[i][mask]
#     294             chi2result[j] = best_chisqr( covinv = covinv, datav=dv, mockv = mv, p=p)
#     295             #print dv.shape,  mv.shape, chi2result[j]
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots()

for i in range(chi2p.shape[0]/5) : 
    ax.plot(bbin, chi2p[i,:], color = 'blue', alpha = 0.1 )#, label='p')
    ax.plot(bbin, chi2x[i,:], color = 'red', alpha = 0.1 )#, label='xi')
    ax.plot(bbin, chi2_diff[i,:], color = 'green', alpha = 0.1)#, label='diff')
    ax.plot(bbin, chi2_com[i,:], color = 'orange', alpha = 0.1 )#, label='com')
ax.plot(bbin, chi2p[0,:], color = 'blue', alpha = 0.5 , label='p')
ax.plot(bbin, chi2x[0,:], color = 'red', alpha = 0.5 , label='xi')
ax.plot(bbin, chi2_diff[0,:], color = 'green', alpha = 0.5, label='diff')
ax.plot(bbin, chi2_com[0,:], color = 'orange', alpha = 0.5 , label='com')
ax.set_xlabel('b')
ax.set_ylabel('chi2')
ax.legend(loc='best')
ax.set_xlim(0.8, 2.2)
ax.set_ylim(0, 5e05)
# Out:
# (0, 500000.0)

# %%
bestfit_b_p, chi2p = getting_sigma_bs( cosmo2, b = bbin, cov = covp_model, datavs = datav_p, 
                                     mockdatavs = p_mock, p=True, kmin=kmin, kmax=kmax )
bestfit_b_xi, chi2x = getting_sigma_bs( cosmo2, b = bbin, cov = covxi_model, datavs = datav_xi, 
                                     mockdatavs = xi_mock, rmin = rmin, rmax=rmax )
bestfit_b_diff ,chi2_diff = getting_sigma_bs_diff( cosmo2, b = bbin, covp = covp_model, covxi = covxi_model, 
                          datavsp = datav_p, datavsxi = datav_xi, 
                          mockdatavsp = p_mock, mockdatavsxi = xi_mock, kmin=kmin, kmax=kmax, rmin=rmin, rmax=rmax )
bestfit_b_com, chi2_com = getting_sigma_bs_com( cosmo2, b = bbin, cov = covtot_model, 
                                     datavs = datav_com, mockdatavs = mocks,
                                    kmin = kmin, kmax = kmax, rmin=rmin, rmax=rmax)
# Out:
# Nk  41  kmin 40  kmax 80
# 53/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-d38ccf64c981> in <module>()
#       1
#       2 bestfit_b_p, chi2p = getting_sigma_bs( cosmo2, b = bbin, cov = covp_model, datavs = datav_p,
# ----> 3                                      mockdatavs = p_mock, p=True, kmin=kmin, kmax=kmax )
#       4 bestfit_b_xi, chi2x = getting_sigma_bs( cosmo2, b = bbin, cov = covxi_model, datavs = datav_xi,
#       5                                      mockdatavs = xi_mock, rmin = rmin, rmax=rmax )
#
# /n/des/lee.5922/Dropbox/repositories/bandpower/SNR/mock_test.py in getting_sigma_bs(cosmo, b, cov, datavs, mockdatavs, p, kmin, kmax, rmin, rmax)
#     334             #mv = mockdatavs[:,i][mask]
#     335             mv = mockdatavs[i][mask]
# --> 336             chi2result[j] = best_chisqr( covinv = covinv, datav=dv, mockv = mv, p=p)
#     337             #print dv.shape,  mv.shape, chi2result[j]
#     338         maxind = np.argmin(chi2result)
#
# /n/des/lee.5922/Dropbox/repositories/bandpower/SNR/mock_test.py in best_chisqr(covinv, datav, mockv, p)
#     286 def best_chisqr( covinv = None, datav=None, mockv = None, p=False):
#     287     d_diff = (datav - mockv)
# --> 288     if p : chisqr = np.sum(d_diff**2 * covinv.diagonal())
#     289     else : chisqr = np.dot(np.dot( d_diff, covinv ), d_diff)
#     290     return chisqr
#
# /n/home00/lee.5922/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1776
#    1777
# -> 1778 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue):
#    1779     """
#    1780     Sum of array elements over a given axis.
#
# KeyboardInterrupt:

# %%
# print out results-------------------------------
sigma_pm, sigma_xm, sigma_cm, sigma_dm \
= np.std(bestfit_b_p), np.std(bestfit_b_xi), np.std(bestfit_b_com), np.std(bestfit_b_diff)
print '---------------------------------\
\n Error on bias (Mock) \n sigma_p      : {} \n sigma_xi     : {} \n sigma_combin : {} \n sigma_diff   : {} \
\n---------------------------------'.format(sigma_pm, sigma_xm, sigma_cm, sigma_dm)
# Out:
# ---------------------------------
#  Error on bias (Mock)
#  sigma_p      : 0.00522347117795
#  sigma_xi     : 0.00683644910292
#  sigma_combin : 0.00291920723927
#  sigma_diff   : 0.00539608714281
# ---------------------------------

# %% [markdown]
# #### Uncorrelated P and Xi mocks

# %%
xi_mock2 = np.vstack((xi_mock[1:,], xi_mock[0,:]))

# %%
mocks2 = np.hstack((p_mock, xi_mock2))
bestfit_b_diff2 = getting_sigma_bs_diff( cosmo2, b = bbin, covp = covp_model, covxi = covxi_model, 
                          datavsp = datav_p, datavsxi = datav_xi, 
                          mockdatavsp = p_mock, mockdatavsxi = xi_mock2, kmin=kmin, kmax=kmax, rmin=rmin, rmax=rmax )
bestfit_b_com2 = getting_sigma_bs_com( cosmo2, b = bbin, cov = covtot_model, 
                                     datavs = datav_com, mockdatavs = mocks2,
                                    kmin = kmin, kmax = kmax, rmin=rmin, rmax=rmax)
# Out:
# Nk  601  kmin 600  kmax 1200
# Nr  80  rmin 89  rmax 10
#  sigma_b : 0.004865911055480486
#  theory : 0.005085374739174752
# N  681  kmin 600  kmax 1200  rmin 89  rmax 10
# Warning : negative diagonal  0
#  sigma_b : 0.5083777381918873
#  theory : 0.0027158689336035003

# %%
# print out results-------------------------------
sigma_cm2, sigma_dm2 = np.std(bestfit_b_com2[0]), np.std(bestfit_b_diff2[0])
print '---------------------------------\
\n Error on bias (Uncorrelated Mock) \n sigma_combin : {} \n sigma_diff   : {} \
\n---------------------------------'.format(sigma_cm2, sigma_dm2)
# Out:
# ---------------------------------
#  Error on bias (Uncorrelated Mock)
#  sigma_combin : 0.508377738192
#  sigma_diff   : 0.00486591105548
# ---------------------------------

# %% [markdown]
# #### Obtain cross bias from bestfit b_p and b_xi

# %%
combine_sigmab(bestfit_b_p, bestfit_b_xi)
# Out:
# cov matrix =
#  |0.0000374033   -0.0005239067|
#  |-0.0005239067   0.0000725793|
#
# sigma_p       : 0.006115820875646229
# sigma_xi      : 0.008519345661117466
# sigma_combin  : nan
# sigma_diff    : 0.0049682011646517265
# ../mock_test.py:524: RuntimeWarning: invalid value encountered in sqrt
#   sig_com = np.sqrt(1./np.sum(F))

# %% [markdown]
# #### Check outliers

# %%
bhist_bin = np.linspace(0.5, 3.5, 1000)
fig, ax = plt.subplots()
_, _, _ = ax.hist( bestfit_b_p, bins = bhist_bin, label = 'sigma_p' )
_, _, _ = ax.hist( bestfit_b_xi, bins = bhist_bin, label = 'sigma_xi', alpha=0.5 )
Nb, _, _ = ax.hist( bestfit_b_com, bins = bhist_bin, label = 'sigma_combine' ,alpha=0.5)
Nb2, _, _ = ax.hist( bestfit_b_diff, bins = bhist_bin, label = 'sigma_diff', alpha = 0.5 )
ax.set_xlabel('bestfit b')
ax.set_ylabel('N');
#ax.set_xlim(1.9, 2.1)
ax.set_xlim(1.4, 1.7)
ax.legend()

nonzero = bhist_bin[:-1][ Nb > 0.0]
nonzero2= bhist_bin[:-1][ Nb2 > 0.0]
print '\nbestfit b exists between b=[{}, {}]'.format(nonzero.min(), nonzero.max() )
print 'bestfit b exists between b=[{}, {}]\n'.format(nonzero2.min(), nonzero2.max() )
# Out:
# bestfit b exists between b=[1.43993993994, 1.44594594595]
# bestfit b exists between b=[1.51501501502, 1.52102102102]

# %% [markdown]
# #### Chi2 distribution test

# %%
chibin = np.linspace(0.5, 1.5, 50)
fig, ax = plt.subplots()
#ax.plot( np.arange(len(chi2p) ), chi2p)
ax.hist(chi2p, bins = chibin, label='p', histtype='step');
ax.hist(chi2x, bins = chibin, label ='xi', histtype='step');
ax.hist(chi2_diff, bins = chibin, label='diff', histtype='step');
ax.hist(chi2_com, bins = chibin, label='combin', histtype='step');
ax.set_xlabel('chi2')
ax.legend()

# %%
print '* with SHOT Noise'

# print out results-------------------------------
print '---------------------------------\
\n#1 Error on bias (Theory) \n sigma_p      : {} \n sigma_xi     : {} \n sigma_combin : {} \n sigma_diff   : {} \
\n---------------------------------'.format(sigma_p, sigma_x, sigma_c, sigma_d)

# print out results-------------------------------
sigma_pm, sigma_xm, sigma_cm, sigma_dm \
= np.std(bestfit_b_p), np.std(bestfit_b_xi), np.std(bestfit_b_com), np.std(bestfit_b_diff)
print '---------------------------------\
\n#2 Error on bias (Mock) \n sigma_p      : {} \n sigma_xi     : {} \n sigma_combin : {} \n sigma_diff   : {} \
\n'.format(sigma_pm, sigma_xm, sigma_cm, sigma_dm)

# print out results-------------------------------
sigma_cm2, sigma_dm2 = np.std(bestfit_b_com2[0]), np.std(bestfit_b_diff2[0])
print ' (Uncorrelated Mock) \n sigma_combin : {} \n sigma_diff   : {} \
\n---------------------------------'.format(sigma_cm2, sigma_dm2)

print '---------------------------------\n\
#3 Error on bias \n \
(Mock, cross bias is obtained \n from bestfit bias of P and Xi)\n'
combine_sigmab(bestfit_b_p, bestfit_b_xi)
# Out:
# * with SHOT Noise
# ---------------------------------
# #1 Error on bias (Theory)
#  sigma_p      : 0.00637045076144
#  sigma_xi     : 0.00844336414134
#  sigma_combin : 0.0027158689336
#  sigma_diff   : 0.00508537473917
# ---------------------------------
# ---------------------------------
# #2 Error on bias (Mock)
#  sigma_p      : 0.00611582087565
#  sigma_xi     : 0.00851934566112
#  sigma_combin : 0.00245030306972
#  sigma_diff   : 0.00637729485262
#
#  (Uncorrelated Mock)
#  sigma_combin : 0.508377738192
#  sigma_diff   : 0.00486591105548
# ---------------------------------
# ---------------------------------
# #3 Error on bias
#  (Mock, cross bias is obtained
#  from bestfit bias of P and Xi)
#
# cov matrix =
#  |0.0000374033   -0.0005239067|
#  |-0.0005239067   0.0000725793|
#
# sigma_p       : 0.006115820875646229
# sigma_xi      : 0.008519345661117466
# sigma_combin  : nan
# sigma_diff    : 0.0049682011646517265

# %% [markdown]
# -------------------

# %% [markdown]
# ==========

# %%
def mock_covariance_xib(xi_model, xi_mock, bestfit_b, b_model):
    #m1, m2 = np.mgrid[0:1, 0:xi_model.size]
    mock_covbxi = np.zeros(( 1, xi_model.size ))
    for i in range(len(xi_mock)) :
        #p = p_mock[i]
        b = bestfit_b[i]
        x = xi_mock[i]
        mock_covbxi += ( b - b_model) * (x - xi_model)
        print '{}/{}                \r'.format(i+1, len(bestfit_b)),
    mock_covbxi = 1./( len(bestfit_b) - 1 ) * mock_covbxi
    
    #if p_model.size == xi_model.size : mock_covpxi = (mock_covpxi + mock_covpxi.T)/2.
    return mock_covbxi


def mock_covariance_pb(p_model, p_mock, bestfit_b, b_model):
    #m1, m2 = np.mgrid[0:1, 0:xi_model.size]
    mock_covbxi = np.zeros(( 1, p_model.size ))
    for i in range(len(p_mock)) :
        #p = p_mock[i]
        b = bestfit_b[i]
        p = p_mock[i]
        mock_covbxi += ( b - b_model) * (p - p_model)
        print '{}/{}                \r'.format(i+1, len(bestfit_b)),
    mock_covbxi = 1./( len(bestfit_b) - 1 ) * mock_covbxi
    
    #if p_model.size == xi_model.size : mock_covpxi = (mock_covpxi + mock_covpxi.T)/2.
    return mock_covbxi

# %%
#kmin = 0.001
#kmax = 0.06
#rmin = 20
#rmax = 200

idx_kmin = get_closest_index_in_data( kmin, cosmo.kbin )   
idx_kmax = get_closest_index_in_data( kmax, cosmo.kbin )

idx_rmin = get_closest_index_in_data( rmin, cosmo.rmin )   
idx_rmax = get_closest_index_in_data( rmax, cosmo.rmax )

rbin = cosmo.rcenter[idx_rmax:idx_rmin]
kbin = cosmo.kcenter[idx_kmin:idx_kmax]

sigma_d = getting_sigma_bs_diff_theory( cosmo2, b = bbin, covp = covp_model, covxi = covxi_model, 
                          datavsp = datav_p, datavsxi = datav_xi, 
                          mockdatavsp = p_mock, mockdatavsxi = xi_mock, kmin=kmin, kmax=kmax, rmin=rmin, rmax=rmax )
sigma_c = getting_sigma_bs_com_theory( cosmo2, b = bbin, cov = covtot_model, 
                                     datavs = datav_com, mockdatavs = mocks,
                                    kmin = kmin, kmax = kmax, rmin=rmin, rmax=rmax)

# print out results-------------------------------
print '---------------------------------\
\n Error on bias (Theory) \n sigma_combin : {} \n sigma_diff   : {} \
\n---------------------------------'.format(sigma_c, sigma_d)
# Out:
# Nk  601  kmin 600  kmax 1200
# Nr  80  rmin 89  rmax 10
#  theory : 0.005085374739174752
# N  681  kmin 600  kmax 1200  rmin 89  rmax 10
# Warning : negative diagonal  0
#  theory : 0.0027158689336035003
# ---------------------------------
#  Error on bias (Theory)
#  sigma_combin : 0.0027158689336
#  sigma_diff   : 0.00508537473917
# ---------------------------------

# %%
Fpp = np.linalg.inv(covp_model[idx_kmin:idx_kmax, idx_kmin:idx_kmax])
Fpb = np.dot(Fpp, dpdb[idx_kmin:idx_kmax])
Cxib = np.dot( covpxi_model[idx_kmin:idx_kmax,idx_rmax:idx_rmin].T, Fpb )  
final = np.dot( np.linalg.inv(covxi_model[idx_rmax:idx_rmin, idx_rmax:idx_rmin]), Cxib)
#mock_covbxi = mock_covariance_xib(xi_model, xi_mock, bestfit_b_p, 2.0)
#final_mock = np.dot(mock_covbxi[:,idx_rmax:idx_rmin], np.linalg.inv(mock_covxi[idx_rmax:idx_rmin, idx_rmax:idx_rmin]) )

# %%
#bestfit_b_p, chi2p = getting_sigma_bs( cosmo2, b = bbin, cov = covp_model, datavs = datav_p, 
#                                     mockdatavs = p_mock, p=True, kmin=kmin, kmax=kmax )
#bestfit_b_xi, chi2x = getting_sigma_bs( cosmo2, b = bbin, cov = covxi_model, datavs = datav_xi, 
#                                     mockdatavs = xi_mock, rmin = rmin, rmax=rmax )
#sigma_pm = np.std(bestfit_b_p)
#sigma_xm = np.std(bestfit_b_xi)

# %%
covdiag = covxi_model[idx_rmax:idx_rmin,idx_rmax:idx_rmin ].diagonal()
DAT = np.column_stack((rbin, Cxib, covdiag, final))
header = 'rbin, cxib, cxi_diag, final, final_mock \n# kmin {} kmax {} rmin {} rmax{}'.format(kmin, kmax, rmin, rmax)
filename = '../data_txt/chris/cov_test_k{:0.2f}_{:0.2f}.txt'.format(kmin, kmax)
np.savetxt(filename, DAT, header=header)

# %%
#Fxi = np.linalg.inv(covxi_model[idx_rmax:idx_rmin, idx_rmax:idx_rmin])
#Fxib = np.dot(Fxi, dxdb[idx_rmax:idx_rmin])
#Cpb = np.dot( covpxi_model[idx_kmin:idx_kmax,idx_rmax:idx_rmin], Fxib )  
#final_p = np.dot( np.linalg.inv(covp_model[idx_kmin:idx_kmax, idx_kmin:idx_kmax]), Cpb)
#mock_covbp = mock_covariance_pb(p_model, p_mock, bestfit_b_xi, 2.0)
#final_mock_p = np.dot(mock_covbp[:,idx_kmin:idx_kmax], np.linalg.inv(mock_covp[idx_kmin:idx_kmax, idx_kmin:idx_kmax]) )

# %%
fig, (ax, ax2, ax3) = plt.subplots(1,3,figsize = (25,5))
ax.plot( rbin,Cxib, label = 'theory')
#ax.plot( rbin,mock_covbxi[:,idx_rmax:idx_rmin].ravel()*5e03, label='mock x 5000')
ax.axhline(y=0, linestyle='--', color='grey')
ax.set_xlabel('r')
ax.set_ylabel(r'~$C_{\xi,b}$')
ax.legend()
#ax.set_ylim(-50000,50000)



ax2.plot( rbin,mock_covxi[idx_rmax:idx_rmin,idx_rmax:idx_rmin ].diagonal(), label='theory')
#ax2.plot( rbin,covxi_model[idx_rmax:idx_rmin,idx_rmax:idx_rmin ].diagonal(), label='mock x 5000')
#ax.plot( cosmo.rcenter, final_mock.ravel())

#ax.plot( cosmo.rcenter, Cxib)
#ax.plot( cosmo.rcenter, mock_covbxi.ravel())
ax2.axhline(y=0, linestyle='--', color='grey')
ax2.set_xlabel('r')
ax2.set_ylabel(r'$C_{\xi}$')
#ax.set_ylim(-50000,50000)
ax2.legend()


ax3.plot( rbin, final, label='theory')
#ax3.plot( rbin, final_mock.ravel()*5e03, label='mock x 5000')
#ax.plot( cosmo.rcenter, Cxib)
#ax.plot( cosmo.rcenter, mock_covbxi.ravel())
ax3.axhline(y=0, linestyle='--', color='grey')
ax3.set_xlabel('r')
ax3.set_ylabel(r'$C_{\xi,b} [C_{\xi}]^{-1}$')
#ax3.set_ylim(-50000,50000)
ax3.legend()

# %%
fig, ax = plt.subplots()
ax.plot( kbin,Cpb)
ax.plot( kbin,mock_covbp[:,idx_kmin:idx_kmax].ravel())
ax.axhline(y=0, linestyle='--', color='grey')
ax.set_xlabel('k')
ax.set_ylabel(r'~$C_{p,b}$')
#ax.set_ylim(-50000,50000)


fig, ax = plt.subplots()
ax.plot( kbin,mock_covp[idx_kmin:idx_kmax,idx_kmin:idx_kmax ].diagonal())
ax.plot( kbin,covp_model[idx_kmin:idx_kmax,idx_kmin:idx_kmax ].diagonal())
#ax.plot( cosmo.rcenter, final_mock.ravel())

#ax.plot( cosmo.rcenter, Cxib)
#ax.plot( cosmo.rcenter, mock_covbxi.ravel())
ax.axhline(y=0, linestyle='--', color='grey')
ax.set_xlabel('k')
ax.set_ylabel(k'$C_{p}$')
#ax.set_ylim(-50000,50000)


fig, ax = plt.subplots()
ax.plot( kbin, final_p)
ax.plot( kbin, final_mock_p.ravel())

#ax.plot( cosmo.rcenter, Cxib)
#ax.plot( cosmo.rcenter, mock_covbxi.ravel())
ax.axhline(y=0, linestyle='--', color='grey')
ax.set_xlabel('k')
ax.set_ylabel(r'$C_{p,b} [C_{p}]^{-1}$')
#ax.set_ylim(-50000,50000)
# Out:
#   File "<ipython-input-27-9cb2aefddbd9>", line 19
#     ax.set_ylabel(k'$C_{p}$')
#                            ^
# SyntaxError: invalid syntax
